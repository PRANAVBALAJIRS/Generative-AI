# %%
# !pip install pypdf2
# !pip install google-cloud-aiplatform
# !pip install google-cloud-storage
# Out:
# Collecting pypdf2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.9 MB/s eta 0:00:00
# Installing collected packages: pypdf2
# Successfully installed pypdf2-3.0.1
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.11/dist-packages (1.99.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.25.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (5.29.5)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (24.2)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=1.32.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (3.34.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (2.1.1)
# Requirement already satisfied: google-genai<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (1.21.1)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (2.11.7)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (4.14.0)
# Requirement already satisfied: docstring_parser<1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform) (0.16)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.32.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.73.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (4.9.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0.0,>=1.32.0->google-cloud-aiplatform) (1.7.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (4.9.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (0.28.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (15.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->google-cloud-aiplatform) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->google-cloud-aiplatform) (0.4.1)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.11/dist-packages (from shapely<3.0.0->google-cloud-aiplatform) (2.0.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.4.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.11/dist-packages (2.19.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.38.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.25.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.32.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2025.6.15)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.6.1)

# %%
from google.cloud import storage
from vertexai.language_models import TextEmbeddingModel
from google.cloud import aiplatform
import PyPDF2

import re
import os
import random
import json
import uuid

# %%
# %ls

# %%
location = ""
pdf_path = "Deepseek.pdf"
bucket_name = "mlaverickpb_rag_demo"
embed_file_path = "rag_demo_embeddings.json"
sentence_file_path = "rag_demo_sentences.json"
index_name = "rag_demo_index"

# %%
def extract_sentences_from_pdf(pdf_path):
  with open(pdf_path, 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    text = ""
    for page in reader.pages:
      if page.extract_text() is not None:
        text += page.extract_text() + " "
  sentences = [sentence.strip() for sentence in text.split('. ') if sentence.strip()]
  return sentences

# %%
def generate_text_embeddings(sentences) -> list:
  # aiplatform.init(project=project, location-location)
    model = TextEmbeddingModel.from_pretrained("text-embedding-005")
    batch_size = 250
    vectors = []

    for i in range(0, len(sentences), batch_size):
        batch = sentences[i:i+batch_size]
        embeddings = model.get_embeddings(batch)
        vectors.extend([embedding.values for embedding in embeddings])

    return vectors

def generate_and_save_embeddings(pdf_path, sentence_file_path, embed_file_path):
  def clean_text(text):
    cleaned_text = re.sub(r'\u2022','', text)# Remove bullet points
    cleaned_text = re.sub(r'\s+',' ', cleaned_text).strip() # Remove extra space
    return cleaned_text

  sentences = extract_sentences_from_pdf(pdf_path)
  if sentences:
    embeddings = generate_text_embeddings(sentences)

    with open(embed_file_path, 'w') as embed_file, open(sentence_file_path, 'w') as sentence_file:
      for sentence, embedding in zip(sentences, embeddings):
        cleaned_sentence = clean_text(sentence)
        id = str(uuid.uuid4())

        embed_item = {"id": id, "embedding": embedding}
        sentence_item = {"id": id, "sentence": cleaned_sentence}

        json.dump(sentence_item, sentence_file)
        sentence_file.write('\n')
        json.dump(embed_item, embed_file)
        embed_file.write('\n')

# %%
def upload_file(bucket_name, file_path):
  storage_client = storage.Client()
  bucket = storage_client.create_bucket(bucket_name,location=location)
  blob = bucket.blob(os.basename(file_path))
  blob.upload_from_filename(file_path)
  print(f"Uploaded {file_path} to gs://{bucket_name}/{os.path.basename(file_path)}")

# %%
def create_vector_index(bucket_name, index_name):
  lakeside_index= aiplatform.MatchingEngineIndex.create_tree_ah_index(
      display_name = index_name,
      contents_delta_uri = f"gs://{bucket_name}/{embed_file_path}",
      dimensions = 768,
      approximate_neighbors_count = 10
  )

  lakeside_index_endpoint = aiplatform.MatchingEngineIndexEndpoint.create(
      display_name = index_name,
      public_endpoint_enabled = True
  )

  lakeside_index_endpoint.deploy_index(
      index = lakeside_index,
      deployed_index_id = index_name
  )

# %%
generate_and_save_embeddings(pdf_path, sentence_file_path, embed_file_path)
upload_file(bucket_name, sentence_file_path)
# Out:
# /usr/local/lib/python3.11/dist-packages/vertexai/_model_garden/_model_garden_models.py:278: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()
# Uploaded rag_demo_sentences.json to gs://mlaverickpb_rag_demo/rag_demo_sentences.json
# ✅ Confirmed: rag_demo_sentences.json exists in bucket.
# Uploaded rag_demo_embeddings.json to gs://mlaverickpb_rag_demo/rag_demo_embeddings.json
# ✅ Confirmed: rag_demo_embeddings.json exists in bucket.

# %%
index_name = "test1"

# %%
create_vector_index(bucket_name, index_name)

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, Part
import json
import os

# %%
location = ""
sentence_file_path = "rag_demo_sentences.json"
# index_name = "rag_demo_index"

# %%
model = GenerativeModel("gemini-2.5-pro")
lakeside_index_ep = aiplatform.MatchingEngineIndexEndpoint(index_endpoint_name = "4460923183049998336")
# Out:
# /usr/local/lib/python3.11/dist-packages/vertexai/generative_models/_generative_models.py:433: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()

# %%
def generate_context(ids, data):
  concatenated_names = ''
  for id in ids:
    for entry in data:
      if entry['id'] == id:
        concatenated_names += entry['sentence'] + "\n"
  return concatenated_names.strip()

def load_file(sentence_file_path):
  data = []
  with open(sentence_file_path, 'r') as f:
    for line in f:
      entry = json.loads(line)
      data.append(entry)
  return data

# %%
data = load_file(sentence_file_path)
data
# Out:
# [{'id': 'b6f4386f-bd90-404e-80a4-a5d466d3a0f9',
#   'sentence': 'DeepSeek-V3 Technical Report DeepSeek-AI research@deepseek.com Abstract We present DeepSeek-V3, a strong Mixture-of-Experts (MoE) language model with 671B total parameters with 37B activated for each token'},
#  {'id': '8b1f8513-8301-4baa-b7c5-65e72711c0d5',
#   'sentence': 'To achieve efficient inference and cost-effective training, DeepSeek-V3 adopts Multi-head Latent Attention (MLA) and DeepSeekMoE architec- tures, which were thoroughly validated in DeepSeek-V2'},
#  {'id': 'bafdf013-0015-43c2-af9c-6cc98723aed8',
#   'sentence': 'Furthermore, DeepSeek-V3 pioneers an auxiliary-loss-free strategy for load balancing and sets a multi-token prediction training objective for stronger performance'},
#  {'id': '45da1598-dec8-4f42-b9b8-23f8e228f6b3',
#   'sentence': 'We pre-train DeepSeek-V3 on 14.8 trillion diverse and high-quality tokens, followed by Supervised Fine-Tuning and Reinforcement Learning stages to fully harness its capabilities'},
#  {'id': 'd716c262-9d17-404d-bc4b-7fe27228a151',
#   'sentence': 'Comprehensive evaluations reveal that DeepSeek-V3 outperforms other open-source models and achieves performance comparable to leading closed-source models'},
#  {'id': 'a40a6740-d9cc-4454-8741-b87d00fa6e27',
#   'sentence': 'Despite its excellent performance, DeepSeek-V3 requires only 2.788M H800 GPU hours for its full training'},
#  {'id': '1a67a826-d4df-4052-9270-599e614c3fa0',
#   'sentence': 'In addition, its training process is remarkably stable'},
#  {'id': '5f9a538c-6414-4b78-b1d2-a469d4646ff0',
#   'sentence': 'Throughout the entire training process, we did not experience any irrecoverable loss spikes or perform any rollbacks. The model checkpoints are available at https://github.com/deepseek-ai/DeepSeek-V3 . MMLU-Pro (EM)GPQA-Diamond (Pass@1)MATH 500 (EM)AIME 2024 (Pass@1)Codeforces (Percentile)SWE-bench Verified (Resolved)020406080100Accuracy / Percentile (%)75.9 59.190.2 39.251.6 42.066.2 41.374.7 16.735.6 22.671.6 49.080.0 23.324.823.873.3 51.173.8 23.325.324.572.6 49.974.6 9.323.638.878.0 65.078.3 16.020.350.8DeepSeek-V3 DeepSeek-V2.5 Qwen2.5-72B-Inst Llama-3.1-405B-Inst GPT-4o-0513 Claude-3.5-Sonnet-1022 Figure 1|Benchmark performance of DeepSeek-V3 and its counterparts.arXiv:2412.19437v2 [cs.CL] 18 Feb 2025 Contents 1 Introduction 4 2 Architecture 6 2.1 Basic Architecture'},
#  {'id': '09775d0c-560a-4396-9774-e092ba6a0700',
#   'sentence': '6 2.1.1 Multi-Head Latent Attention'},
#  {'id': 'aed7e401-ef2d-4af5-8a24-747c2160cf0f',
#   'sentence': '7 2.1.2 DeepSeekMoE with Auxiliary-Loss-Free Load Balancing'},
#  {'id': '5a6d346a-4484-476d-ad60-a60323662dd7',
#   'sentence': '8 2.2 Multi-Token Prediction'},
#  {'id': 'bf2f0d93-343f-40a2-9917-c997d0e21903',
#   'sentence': '10 3 Infrastructures 11 3.1 Compute Clusters'},
#  {'id': '556807ec-a6f3-412c-95da-cf7157589a86',
#   'sentence': '11 3.2 Training Framework'},
#  {'id': '968b3e97-cdd1-47cc-bd66-0b8e47912938',
#   'sentence': '12 3.2.1 DualPipe and Computation-Communication Overlap'},
#  {'id': '3b6f02bf-df24-4d31-9910-7289cecae60b',
#   'sentence': '12 3.2.2 Efficient Implementation of Cross-Node All-to-All Communication'},
#  {'id': 'c7d93481-4ca9-483c-9e52-ca3c6e7db64f',
#   'sentence': '13 3.2.3 Extremely Memory Saving with Minimal Overhead'},
#  {'id': '814b20b5-e9a4-4cbd-b1cf-552d6d7c9ab2',
#   'sentence': '14 3.3 FP8 Training'},
#  {'id': '955bf765-76ac-4824-9c35-b7973f73c44d',
#   'sentence': '14 3.3.1 Mixed Precision Framework'},
#  {'id': 'a9e52edd-e651-4bd1-9e25-38754d046573',
#   'sentence': '15 3.3.2 Improved Precision from Quantization and Multiplication'},
#  {'id': '7bc2163c-4702-41a0-97b6-7264a555cf77',
#   'sentence': '16 3.3.3 Low-Precision Storage and Communication'},
#  {'id': '15f43eee-e88e-4b3c-af36-c1ae8830e6a9',
#   'sentence': '18 3.4 Inference and Deployment'},
#  {'id': '4882dad1-1293-4f15-ae3b-a0d729dd1c4c',
#   'sentence': '18 3.4.1 Prefilling'},
#  {'id': '59a4c2a6-74aa-4098-a660-74487a9dc016',
#   'sentence': '19 3.4.2 Decoding'},
#  {'id': 'ee5ec81b-9e37-4313-aaa3-44254be25f47',
#   'sentence': '19 3.5 Suggestions on Hardware Design'},
#  {'id': 'e04f1404-687d-4c29-8802-df32b722dc3d',
#   'sentence': '20 3.5.1 Communication Hardware'},
#  {'id': '8ae79e47-e204-49d3-8b3a-794deb6350d8',
#   'sentence': '20 3.5.2 Compute Hardware'},
#  {'id': 'ae0cd4c0-42ea-4d0e-8be0-5cb37b8da562',
#   'sentence': '20 4 Pre-Training 21 4.1 Data Construction'},
#  {'id': '6535956c-55fc-4534-a645-13bff18cea67',
#   'sentence': '21 4.2 Hyper-Parameters'},
#  {'id': '10527814-9cc3-4415-b912-5de961b4f14a',
#   'sentence': '22 4.3 Long Context Extension'},
#  {'id': '9c89f581-0d59-4b7d-9c75-d21af59dc2c3',
#   'sentence': '23 4.4 Evaluations'},
#  {'id': 'cf233974-27bf-4083-8905-b4cb23c0ff81',
#   'sentence': '24 4.4.1 Evaluation Benchmarks'},
#  {'id': 'bfa9f75a-ab90-4737-9763-5636695ddd5b',
#   'sentence': '24 4.4.2 Evaluation Results'},
#  {'id': '029f0ec7-9907-489d-b539-f42d9e508fd5',
#   'sentence': '24 4.5 Discussion'},
#  {'id': 'd82ba82b-4602-4e94-b262-fab041c4c6bc',
#   'sentence': '26 4.5.1 Ablation Studies for Multi-Token Prediction'},
#  {'id': 'a7c9907a-7609-4168-bc94-bd029df5e1f0',
#   'sentence': '26 4.5.2 Ablation Studies for the Auxiliary-Loss-Free Balancing Strategy'},
#  {'id': '8f915c30-3b31-4145-bf4c-4e76eecf812a',
#   'sentence': '26 2 4.5.3 Batch-Wise Load Balance VS'},
#  {'id': 'ad99e066-43dc-493f-be3e-8b1762b5d2b0',
#   'sentence': 'Sequence-Wise Load Balance'},
#  {'id': 'a76a26e3-5047-4334-837b-11e85b7e980e',
#   'sentence': '27 5 Post-Training 28 5.1 Supervised Fine-Tuning'},
#  {'id': '77220b26-354f-41c5-b043-b1e6ca5c0a4e',
#   'sentence': '28 5.2 Reinforcement Learning'},
#  {'id': 'ca441b3e-0d97-4c6a-9ca9-82b0f9550c51',
#   'sentence': '29 5.2.1 Reward Model'},
#  {'id': '5e797332-0ee1-4d33-bc4c-8a2993060421',
#   'sentence': '29 5.2.2 Group Relative Policy Optimization'},
#  {'id': 'd910a029-4d67-4b59-86ea-bbd24de6a564',
#   'sentence': '30 5.3 Evaluations'},
#  {'id': 'e2547c71-a25f-4099-8ebe-70c51bb1ab57',
#   'sentence': '30 5.3.1 Evaluation Settings'},
#  {'id': 'c4528701-d535-42cb-98cc-3d0634ab9f40',
#   'sentence': '30 5.3.2 Standard Evaluation'},
#  {'id': '48a56031-bf35-4f9a-b900-93d4cf6f329a',
#   'sentence': '31 5.3.3 Open-Ended Evaluation'},
#  {'id': '540ca8ae-f29e-4cd6-9842-f23cc834dde2',
#   'sentence': '33 5.3.4 DeepSeek-V3 as a Generative Reward Model'},
#  {'id': '864aad7e-6e0b-4fe8-9f7b-b99b82e840af',
#   'sentence': '33 5.4 Discussion'},
#  {'id': '551469f4-184a-496d-964e-b2cc46397736',
#   'sentence': '34 5.4.1 Distillation from DeepSeek-R1'},
#  {'id': '6868fb87-0c62-4c45-a534-61388348e333',
#   'sentence': '34 5.4.2 Self-Rewarding'},
#  {'id': '1e0c116e-0565-4824-a652-4cd2f375289c',
#   'sentence': '34 5.4.3 Multi-Token Prediction Evaluation'},
#  {'id': 'f68a22f3-9d00-4566-85aa-197e440dd8c8',
#   'sentence': '35 6 Conclusion, Limitations, and Future Directions 35 A Contributions and Acknowledgments 45 B Ablation Studies for Low-Precision Training 47 B.1 FP8 v.s'},
#  {'id': '7f164d82-7c69-4c73-b0c7-2f9813ce064c', 'sentence': 'BF16 Training'},
#  {'id': '5e5cb8bd-71c1-45ce-99e3-7673ff6f27e2',
#   'sentence': '47 B.2 Discussion About Block-Wise Quantization'},
#  {'id': '78f27e94-77d0-4e05-b58e-1d421aedda85',
#   'sentence': '47 C Expert Specialization Patterns of the 16B Aux-Loss-Based and Aux-Loss-Free Models 48 3 1'},
#  {'id': 'cf28e0d5-945d-4d62-82b8-1e662e8ff333',
#   'sentence': 'Introduction In recent years, Large Language Models (LLMs) have been undergoing rapid iteration and evolution (Anthropic, 2024; Google, 2024; OpenAI, 2024a), progressively diminishing the gap to- wards Artificial General Intelligence (AGI)'},
#  {'id': 'd6278ac7-0328-4102-9532-3dfe8c88d399',
#   'sentence': 'Beyond closed-source models, open-source models, including DeepSeek series (DeepSeek-AI, 2024a,b,c; Guo et al., 2024), LLaMA series (AI@Meta, 2024a,b; Touvron et al., 2023a,b), Qwen series (Qwen, 2023, 2024a,b), and Mistral series (Jiang et al., 2023; Mistral, 2024), are also making significant strides, endeavoring to close the gap with their closed-source counterparts'},
#  {'id': '22f6f750-b53b-482f-a12f-71eff1fb6491',
#   'sentence': 'To further push the boundaries of open-source model capa- bilities, we scale up our models and introduce DeepSeek-V3, a large Mixture-of-Experts (MoE) model with 671B parameters, of which 37B are activated for each token. With a forward-looking perspective, we consistently strive for strong model performance and economical costs'},
#  {'id': 'b1dfbebf-3a1a-4dab-ad9d-baa470fa126f',
#   'sentence': 'Therefore, in terms of architecture, DeepSeek-V3 still adopts Multi-head Latent Attention (MLA) (DeepSeek-AI, 2024c) for efficient inference and DeepSeekMoE (Dai et al., 2024) for cost-effective training'},
#  {'id': '44cb6628-a2a2-410d-8daf-0d7fdf0dccc8',
#   'sentence': 'These two architectures have been validated in DeepSeek- V2 (DeepSeek-AI, 2024c), demonstrating their capability to maintain robust model performance while achieving efficient training and inference'},
#  {'id': '78096219-ce71-4bf4-89a4-c5de2dc9da50',
#   'sentence': 'Beyond the basic architecture, we implement two additional strategies to further enhance the model capabilities'},
#  {'id': '06909d26-eaeb-432d-a905-c33b072554b5',
#   'sentence': 'Firstly, DeepSeek-V3 pi- oneers an auxiliary-loss-free strategy (Wang et al., 2024a) for load balancing, with the aim of minimizing the adverse impact on model performance that arises from the effort to encourage load balancing'},
#  {'id': '74353415-b398-4b92-ad67-e56415ee6872',
#   'sentence': 'Secondly, DeepSeek-V3 employs a multi-token prediction training objective, which we have observed to enhance the overall performance on evaluation benchmarks. In order to achieve efficient training, we support the FP8 mixed precision training and implement comprehensive optimizations for the training framework'},
#  {'id': '22ce27c6-9d08-45ea-8aeb-4fb03b7710dc',
#   'sentence': 'Low-precision training has emerged as a promising solution for efficient training (Dettmers et al., 2022; Kalamkar et al., 2019; Narang et al., 2017; Peng et al., 2023b), its evolution being closely tied to advancements in hardware capabilities (Luo et al., 2024; Micikevicius et al., 2022; Rouhani et al., 2023a)'},
#  {'id': '66071cae-abc5-4118-a601-0fe828d91949',
#   'sentence': 'In this work, we introduce an FP8 mixed precision training framework and, for the first time, validate its effectiveness on an extremely large-scale model'},
#  {'id': 'eb25254d-e34b-4e76-8564-13c077cf44f1',
#   'sentence': 'Through the support for FP8 computation and storage, we achieve both accelerated training and reduced GPU memory usage'},
#  {'id': 'a2a448c0-d59c-4e54-b33e-7d231db6c420',
#   'sentence': 'As for the training framework, we design the DualPipe algorithm for efficient pipeline parallelism, which has fewer pipeline bubbles and hides most of the communication during training through computation-communication overlap'},
#  {'id': 'd53be5ec-ef50-4c8a-9936-6742d2f8643b',
#   'sentence': 'This overlap ensures that, as the model further scales up, as long as we maintain a constant computation-to-communication ratio, we can still employ fine-grained experts across nodes while achieving a near-zero all-to-all communication overhead. In addition, we also develop efficient cross-node all-to-all communication kernels to fully utilize InfiniBand (IB) and NVLink bandwidths'},
#  {'id': 'f20e9ffa-979f-4749-8a9f-72c74eb14085',
#   'sentence': 'Furthermore, we meticulously optimize the memory footprint, making it possible to train DeepSeek-V3 without using costly tensor parallelism. Combining these efforts, we achieve high training efficiency. During pre-training, we train DeepSeek-V3 on 14.8T high-quality and diverse tokens'},
#  {'id': '71ef2466-2de3-4585-b5d2-7eb5610f57ed',
#   'sentence': 'The pre-training process is remarkably stable'},
#  {'id': 'd73648cc-3ecd-4d07-81d4-24e04b3024b7',
#   'sentence': 'Throughout the entire training process, we did not encounter any irrecoverable loss spikes or have to roll back'},
#  {'id': '9f514c5b-9727-4e8f-85e1-c932b20c161d',
#   'sentence': 'Next, we conduct a two-stage context length extension for DeepSeek-V3'},
#  {'id': 'dfdb0cb0-5f35-43c1-9042-386c7ac2329c',
#   'sentence': 'In the first stage, the maximum context length is extended to 32K, and in the second stage, it is further extended to 128K'},
#  {'id': 'da5d4645-65db-4709-a5d6-aa06b38ca9af',
#   'sentence': 'Following this, we conduct post-training, including Supervised Fine-Tuning (SFT) and Reinforcement Learning (RL) on the base model of DeepSeek-V3, to align it with human preferences and further unlock its potential'},
#  {'id': '46495f19-b854-4ab7-9112-a5fd4f9ff171',
#   'sentence': 'During the post-training stage, we distill the reasoning capability from the DeepSeek- R1 series of models, and meanwhile carefully maintain the balance between model accuracy 4 Training Costs Pre-Training Context Extension Post-Training Total in H800 GPU Hours 2664K 119K 5K 2788K in USD $5.328M $0.238M $0.01M $5.576M Table 1|Training costs of DeepSeek-V3, assuming the rental price of H800 is $2 per GPU hour. and generation length. We evaluate DeepSeek-V3 on a comprehensive array of benchmarks'},
#  {'id': 'b4647da3-41e2-4b3e-a8be-2bc60012c299',
#   'sentence': 'Despite its economical training costs, comprehensive evaluations reveal that DeepSeek-V3-Base has emerged as the strongest open-source base model currently available, especially in code and math'},
#  {'id': '683259ee-a52d-4185-9f47-ba5da8863eae',
#   'sentence': 'Its chat version also outperforms other open-source models and achieves performance comparable to leading closed-source models, including GPT-4o and Claude-3.5-Sonnet, on a series of standard and open-ended benchmarks. Lastly, we emphasize again the economical training costs of DeepSeek-V3, summarized in Table 1, achieved through our optimized co-design of algorithms, frameworks, and hardware. During the pre-training stage, training DeepSeek-V3 on each trillion tokens requires only 180K H800 GPU hours, i.e., 3.7 days on our cluster with 2048 H800 GPUs'},
#  {'id': 'fded78a1-c48e-44b3-9c63-7a72b8bb6299',
#   'sentence': 'Consequently, our pre- training stage is completed in less than two months and costs 2664K GPU hours'},
#  {'id': '9b249d6a-fbf9-49c9-8365-78637ef3adf6',
#   'sentence': 'Combined with 119K GPU hours for the context length extension and 5K GPU hours for post-training, DeepSeek-V3 costs only 2.788M GPU hours for its full training'},
#  {'id': '0d94bc88-64e4-463d-be4f-1b178f530dae',
#   'sentence': 'Assuming the rental price of the H800 GPU is $2 per GPU hour, our total training costs amount to only $5.576M'},
#  {'id': '2612a271-bb9d-4c51-bb13-efd5fc05fad6',
#   'sentence': 'Note that the aforementioned costs include only the official training of DeepSeek-V3, excluding the costs associated with prior research and ablation experiments on architectures, algorithms, or data. Our main contribution includes: Architecture: Innovative Load Balancing Strategy and Training Objective On top of the efficient architecture of DeepSeek-V2, we pioneer an auxiliary-loss-free strategy for load balancing, which minimizes the performance degradation that arises from encouraging load balancing. We investigate a Multi-Token Prediction (MTP) objective and prove it beneficial to model performance'},
#  {'id': '90832d87-a7a8-483a-bf0a-a75d240594ed',
#   'sentence': 'It can also be used for speculative decoding for inference acceleration. Pre-Training: Towards Ultimate Training Efficiency We design an FP8 mixed precision training framework and, for the first time, validate the feasibility and effectiveness of FP8 training on an extremely large-scale model. Through the co-design of algorithms, frameworks, and hardware, we overcome the communication bottleneck in cross-node MoE training, achieving near-full computation- communication overlap'},
#  {'id': 'c1ff01fa-968a-44ff-b492-173f24a16c45',
#   'sentence': 'This significantly enhances our training efficiency and reduces the training costs, enabling us to further scale up the model size without additional overhead. At an economical cost of only 2.664M H800 GPU hours, we complete the pre-training of DeepSeek-V3 on 14.8T tokens, producing the currently strongest open-source base model. The subsequent training stages after pre-training require only 0.1M GPU hours. Post-Training: Knowledge Distillation from DeepSeek-R1 We introduce an innovative methodology to distill reasoning capabilities from the long- Chain-of-Thought (CoT) model, specifically from one of the DeepSeek R1 series models, into standard LLMs, particularly DeepSeek-V3'},
#  {'id': 'b52f4078-68a4-41c1-8869-edf9fae9d3bb',
#   'sentence': 'Our pipeline elegantly incorporates the 5 verification and reflection patterns of R1 into DeepSeek-V3 and notably improves its reasoning performance'},
#  {'id': '8aee8119-428d-4b8a-9133-bc32b5e06906',
#   'sentence': 'Meanwhile, we also maintain control over the output style and length of DeepSeek-V3. Summary of Core Evaluation Results Knowledge : (1) On educational benchmarks such as MMLU, MMLU-Pro, and GPQA, DeepSeek-V3 outperforms all other open-source models, achieving 88.5 on MMLU, 75.9 on MMLU-Pro, and 59.1 on GPQA'},
#  {'id': '15da7849-d71d-4182-a0b1-8d936151510c',
#   'sentence': 'Its performance is comparable to leading closed-source models like GPT-4o and Claude-Sonnet-3.5, narrowing the gap between open-source and closed-source models in this domain'},
#  {'id': 'd0dd6245-ff65-4d6a-8236-e8686940d4b3',
#   'sentence': '(2) For factuality benchmarks, DeepSeek-V3 demonstrates superior performance among open-source models on both SimpleQA and Chinese SimpleQA'},
#  {'id': '0e3ccda6-bf35-4848-bdd5-b6e26845f778',
#   'sentence': 'While it trails behind GPT-4o and Claude-Sonnet-3.5 in English factual knowledge (SimpleQA), it surpasses these models in Chinese factual knowledge (Chinese SimpleQA), highlighting its strength in Chinese factual knowledge. Code, Math, and Reasoning : (1) DeepSeek-V3 achieves state-of-the-art performance on math-related benchmarks among all non-long-CoT open-source and closed-source models. Notably, it even outperforms o1-preview on specific benchmarks, such as MATH-500, demonstrating its robust mathematical reasoning capabilities'},
#  {'id': '69d4ecc1-e95b-44bf-a475-b7d4bdf714f6',
#   'sentence': '(2) On coding-related tasks, DeepSeek-V3 emerges as the top-performing model for coding competition benchmarks, such as LiveCodeBench, solidifying its position as the leading model in this domain'},
#  {'id': '5f7c7272-a501-42dd-9875-8d7e7f7c5869',
#   'sentence': 'For engineering-related tasks, while DeepSeek-V3 performs slightly below Claude-Sonnet-3.5, it still outpaces all other models by a significant margin, demonstrating its competitiveness across diverse technical benchmarks. In the remainder of this paper, we first present a detailed exposition of our DeepSeek-V3 model architecture (Section 2)'},
#  {'id': '537daf77-fef9-415c-8f13-6d08e558b4fb',
#   'sentence': 'Subsequently, we introduce our infrastructures, encompassing our compute clusters, the training framework, the support for FP8 training, the inference deployment strategy, and our suggestions on future hardware design'},
#  {'id': '4df71d65-79cc-4f37-8db5-74c89955729d',
#   'sentence': 'Next, we describe our pre-training process, including the construction of training data, hyper-parameter settings, long- context extension techniques, the associated evaluations, as well as some discussions (Section 4). Thereafter, we discuss our efforts on post-training, which include Supervised Fine-Tuning (SFT), Reinforcement Learning (RL), the corresponding evaluations, and discussions (Section 5)'},
#  {'id': '9f701e2b-3241-4d6e-b118-d2f78675889a',
#   'sentence': 'Lastly, we conclude this work, discuss existing limitations of DeepSeek-V3, and propose potential directions for future research (Section 6). 2'},
#  {'id': 'b20a1e0e-0ee4-4169-9de3-cd5a20c430ed',
#   'sentence': 'Architecture We first introduce the basic architecture of DeepSeek-V3, featured by Multi-head Latent Atten- tion (MLA) (DeepSeek-AI, 2024c) for efficient inference and DeepSeekMoE (Dai et al., 2024) for economical training'},
#  {'id': 'cdcee9d1-dce0-4db1-bde7-6a643e9eaf47',
#   'sentence': 'Then, we present a Multi-Token Prediction (MTP) training objective, which we have observed to enhance the overall performance on evaluation benchmarks'},
#  {'id': '623ee3da-2e50-4187-b3fb-328f18283d1a',
#   'sentence': 'For other minor details not explicitly mentioned, DeepSeek-V3 adheres to the settings of DeepSeek- V2 (DeepSeek-AI, 2024c). 2.1'},
#  {'id': 'a582733e-2693-49d4-9b69-f2731be05fe3',
#   'sentence': 'Basic Architecture The basic architecture of DeepSeek-V3 is still within the Transformer (Vaswani et al., 2017) framework'},
#  {'id': 'e4b744e1-a3a0-425e-af5d-d34a49af3f87',
#   'sentence': 'For efficient inference and economical training, DeepSeek-V3 also adopts MLA and DeepSeekMoE, which have been thoroughly validated by DeepSeek-V2'},
#  {'id': '5e17e799-b3d8-4098-a7ec-86015b68b92b',
#   'sentence': 'Compared with DeepSeek-V2, an exception is that we additionally introduce an auxiliary-loss-free load balancing 6 … Router Input Hidden 𝐮𝐮𝑡𝑡Output Hidden 𝐡𝐡𝑡𝑡′ 1 𝑁𝑁𝑠𝑠 1 2 𝑁𝑁𝑟𝑟-1𝑁𝑁𝑟𝑟Shared ExpertRouted Expert Top-𝐾𝐾𝑟𝑟 AttentionFeed -Forward Network… 3 4 RMSNormRMSNormTransformer Block ×𝐿𝐿DeepSeekMoE 0 Input Hidden 𝐡𝐡𝑡𝑡Multi -Head Latent Attention (MLA) 0 {𝐪𝐪𝑡𝑡,𝑖𝑖𝐶𝐶} {𝐯𝐯𝑡𝑡,𝑖𝑖𝐶𝐶} {𝐤𝐤𝑡𝑡,𝑖𝑖𝐶𝐶} Latent 𝐜𝐜𝑡𝑡𝐾𝐾𝐾𝐾Latent 𝐜𝐜𝑡𝑡𝑄𝑄{𝐪𝐪𝑡𝑡,𝑖𝑖𝑅𝑅} 𝐤𝐤𝑡𝑡𝑅𝑅Cached During Inference Multi- Head Attention concatenate concatenate{[𝐪𝐪𝑡𝑡,𝑖𝑖𝐶𝐶;𝐪𝐪𝑡𝑡,𝑖𝑖𝑅𝑅]} {[𝐤𝐤𝑡𝑡,𝑖𝑖𝐶𝐶;𝐤𝐤𝑡𝑡𝑅𝑅]} …Output Hidden 𝐮𝐮𝑡𝑡 …………… 1…… ……apply RoPEapply RoPEFigure 2|Illustration of the basic architecture of DeepSeek-V3'},
#  {'id': 'b5302c2d-256e-45cf-8263-b05bfe2d63f6',
#   'sentence': 'Following DeepSeek-V2, we adopt MLA and DeepSeekMoE for efficient inference and economical training. strategy (Wang et al., 2024a) for DeepSeekMoE to mitigate the performance degradation induced by the effort to ensure load balance'},
#  {'id': 'a563044a-814f-4126-8747-1430ad2d83f0',
#   'sentence': 'Figure 2 illustrates the basic architecture of DeepSeek-V3, and we will briefly review the details of MLA and DeepSeekMoE in this section. 2.1.1'},
#  {'id': '735b04a5-1666-40dc-a524-a0603e1c6c2f',
#   'sentence': 'Multi-Head Latent Attention For attention, DeepSeek-V3 adopts the MLA architecture'},
#  {'id': '579572cd-549f-4f34-ad7c-94ff59e91aad',
#   'sentence': 'Let 𝑑denote the embedding dimen- sion,𝑛ℎdenote the number of attention heads, 𝑑ℎdenote the dimension per head, and h𝑡∈R𝑑 denote the attention input for the 𝑡-th token at a given attention layer'},
#  {'id': '00e9e17e-6d32-46ca-bc50-2b99d5ecac9f',
#   'sentence': 'The core of MLA is the low-rank joint compression for attention keys and values to reduce Key-Value (KV) cache during inference: c𝐾𝑉 𝑡=𝑊𝐷𝐾𝑉h𝑡, (1) [k𝐶 𝑡,1;k𝐶 𝑡,2; ...;k𝐶 𝑡,𝑛ℎ]=k𝐶 𝑡=𝑊𝑈𝐾c𝐾𝑉 𝑡, (2) k𝑅 𝑡=RoPE(𝑊𝐾𝑅h𝑡), (3) k𝑡,𝑖=[k𝐶 𝑡,𝑖;k𝑅 𝑡], (4) [v𝐶 𝑡,1;v𝐶 𝑡,2; ...;v𝐶 𝑡,𝑛ℎ]=v𝐶 𝑡=𝑊𝑈𝑉c𝐾𝑉 𝑡, (5) 7 where c𝐾𝑉 𝑡∈R𝑑𝑐is the compressed latent vector for keys and values; 𝑑𝑐(≪𝑑ℎ𝑛ℎ)indicates the KV compression dimension; 𝑊𝐷𝐾𝑉∈R𝑑𝑐×𝑑denotes the down-projection matrix; 𝑊𝑈𝐾,𝑊𝑈𝑉∈R𝑑ℎ𝑛ℎ×𝑑𝑐 are the up-projection matrices for keys and values, respectively; 𝑊𝐾𝑅∈R𝑑𝑅 ℎ×𝑑is the matrix used to produce the decoupled key that carries Rotary Positional Embedding (RoPE) (Su et al., 2024); RoPE(·)denotes the operation that applies RoPE matrices; and [·;·]denotes concatenation'},
#  {'id': '158850de-1f18-4440-8b39-dde55a374548',
#   'sentence': 'Note that for MLA, only the blue-boxed vectors (i.e., c𝐾𝑉 𝑡and k𝑅 𝑡) need to be cached during generation, which results in significantly reduced KV cache while maintaining performance comparable to standard Multi-Head Attention (MHA) (Vaswani et al., 2017). For the attention queries, we also perform a low-rank compression, which can reduce the activation memory during training: c𝑄 𝑡=𝑊𝐷𝑄h𝑡, (6) [q𝐶 𝑡,1;q𝐶 𝑡,2; ...;q𝐶 𝑡,𝑛ℎ]=q𝐶 𝑡=𝑊𝑈𝑄c𝑄 𝑡, (7) [q𝑅 𝑡,1;q𝑅 𝑡,2; ...;q𝑅 𝑡,𝑛ℎ]=q𝑅 𝑡=RoPE(𝑊𝑄𝑅c𝑄 𝑡), (8) q𝑡,𝑖=[q𝐶 𝑡,𝑖;q𝑅 𝑡,𝑖], (9) where c𝑄 𝑡∈R𝑑′ 𝑐is the compressed latent vector for queries; 𝑑′ 𝑐(≪𝑑ℎ𝑛ℎ)denotes the query compression dimension; 𝑊𝐷𝑄∈R𝑑′ 𝑐×𝑑,𝑊𝑈𝑄∈R𝑑ℎ𝑛ℎ×𝑑′ 𝑐are the down-projection and up-projection matrices for queries, respectively; and 𝑊𝑄𝑅∈R𝑑𝑅 ℎ𝑛ℎ×𝑑′ 𝑐is the matrix to produce the decoupled queries that carry RoPE. Ultimately, the attention queries ( q𝑡,𝑖), keys ( k𝑗,𝑖), and values ( v𝐶 𝑗,𝑖) are combined to yield the final attention output u𝑡: o𝑡,𝑖=𝑡∑︁ 𝑗=1Softmax 𝑗(q𝑇 𝑡,𝑖k𝑗,𝑖 √︃ 𝑑ℎ+𝑑𝑅 ℎ)v𝐶 𝑗,𝑖, (10) u𝑡=𝑊𝑂[o𝑡,1;o𝑡,2; ...;o𝑡,𝑛ℎ], (11) where𝑊𝑂∈R𝑑×𝑑ℎ𝑛ℎdenotes the output projection matrix. 2.1.2'},
#  {'id': 'afcffe09-4220-48f2-85b0-c60f23de26bc',
#   'sentence': 'DeepSeekMoE with Auxiliary-Loss-Free Load Balancing Basic Architecture of DeepSeekMoE'},
#  {'id': '9c7eeede-9bc4-4c68-809d-d2f69933a1e1',
#   'sentence': 'For Feed-Forward Networks (FFNs), DeepSeek-V3 employs the DeepSeekMoE architecture (Dai et al., 2024)'},
#  {'id': '3f545223-672a-4dc0-b3a6-7377e21e969a',
#   'sentence': 'Compared with traditional MoE architectures like GShard (Lepikhin et al., 2021), DeepSeekMoE uses finer-grained experts and isolates some experts as shared ones'},
#  {'id': '65cdc603-7cba-4f4c-b6a5-9ac11c8fe1da',
#   'sentence': 'Let u𝑡denote the FFN input of the 𝑡-th token, we compute the FFN output h′ 𝑡as follows: h′ 𝑡=u𝑡+𝑁𝑠∑︁ 𝑖=1FFN(𝑠) 𝑖(u𝑡)+𝑁𝑟∑︁ 𝑖=1𝑔𝑖,𝑡FFN(𝑟) 𝑖(u𝑡), (12) 𝑔𝑖,𝑡=𝑔′ 𝑖,𝑡Í𝑁𝑟 𝑗=1𝑔′ 𝑗,𝑡, (13) 𝑔′ 𝑖,𝑡=( 𝑠𝑖,𝑡,𝑠𝑖,𝑡∈Topk({𝑠𝑗,𝑡|1⩽𝑗⩽𝑁𝑟},𝐾𝑟), 0, otherwise,(14) 𝑠𝑖,𝑡=Sigmoid\x00u𝑡𝑇e𝑖\x01, (15) 8 where𝑁𝑠and𝑁𝑟denote the numbers of shared experts and routed experts, respectively; FFN(𝑠) 𝑖(·) and FFN(𝑟) 𝑖(·)denote the 𝑖-th shared expert and the 𝑖-th routed expert, respectively; 𝐾𝑟denotes the number of activated routed experts; 𝑔𝑖,𝑡is the gating value for the 𝑖-th expert; 𝑠𝑖,𝑡is the token-to-expert affinity; e𝑖is the centroid vector of the 𝑖-th routed expert; and Topk(·,𝐾)denotes the set comprising 𝐾highest scores among the affinity scores calculated for the 𝑡-th token and all routed experts'},
#  {'id': '220029eb-2d8a-4fe8-a7e5-1f8e733fac7f',
#   'sentence': 'Slightly different from DeepSeek-V2, DeepSeek-V3 uses the sigmoid function to compute the affinity scores, and applies a normalization among all selected affinity scores to produce the gating values. Auxiliary-Loss-Free Load Balancing'},
#  {'id': '1aafa6d3-13a5-42ff-9439-9654455354f3',
#   'sentence': 'For MoE models, an unbalanced expert load will lead to routing collapse (Shazeer et al., 2017) and diminish computational efficiency in scenarios with expert parallelism'},
#  {'id': '67668639-8840-4afc-aca2-45440f0b9e43',
#   'sentence': 'Conventional solutions usually rely on the auxiliary loss (Fedus et al., 2021; Lepikhin et al., 2021) to avoid unbalanced load'},
#  {'id': '917c1ce9-725c-4144-a6ca-6fcea0e10401',
#   'sentence': 'However, too large an auxiliary loss will impair the model performance (Wang et al., 2024a)'},
#  {'id': 'ec92e4f5-27c2-45fd-9f90-e8f91d14c2ba',
#   'sentence': 'To achieve a better trade-off between load balance and model performance, we pioneer an auxiliary-loss-free load balancing strategy (Wang et al., 2024a) to ensure load balance'},
#  {'id': '89e11762-0dc2-4698-bf27-f85a722da5f7',
#   'sentence': 'To be specific, we introduce a bias term 𝑏𝑖for each expert and add it to the corresponding affinity scores 𝑠𝑖,𝑡to determine the top-K routing: 𝑔′ 𝑖,𝑡=( 𝑠𝑖,𝑡,𝑠𝑖,𝑡+𝑏𝑖∈Topk({𝑠𝑗,𝑡+𝑏𝑗|1⩽𝑗⩽𝑁𝑟},𝐾𝑟), 0, otherwise.(16) Note that the bias term is only used for routing'},
#  {'id': '7f4a70b6-5c4a-4ce9-a059-7932be8f8df1',
#   'sentence': 'The gating value, which will be multiplied with the FFN output, is still derived from the original affinity score 𝑠𝑖,𝑡'},
#  {'id': '77e95360-15ee-4e04-8f22-55207e0675f3',
#   'sentence': 'During training, we keep monitoring the expert load on the whole batch of each training step'},
#  {'id': 'd18003c4-262f-4f93-8650-1514a02e83fa',
#   'sentence': 'At the end of each step, we will decrease the bias term by 𝛾if its corresponding expert is overloaded, and increase it by 𝛾if its corresponding expert is underloaded, where 𝛾is a hyper-parameter called bias update speed'},
#  {'id': 'bd132038-e11b-4f8d-9e47-5e750b4e178e',
#   'sentence': 'Through the dynamic adjustment, DeepSeek-V3 keeps balanced expert load during training, and achieves better performance than models that encourage load balance through pure auxiliary losses. Complementary Sequence-Wise Auxiliary Loss'},
#  {'id': 'e6ea77d0-058e-43c7-a44b-ffbf9ba4fd2b',
#   'sentence': 'Although DeepSeek-V3 mainly relies on the auxiliary-loss-free strategy for load balance, to prevent extreme imbalance within any single sequence, we also employ a complementary sequence-wise balance loss: LBal=𝛼𝑁𝑟∑︁ 𝑖=1𝑓𝑖𝑃𝑖, (17) 𝑓𝑖=𝑁𝑟 𝐾𝑟𝑇𝑇∑︁ 𝑡=11\x00 𝑠𝑖,𝑡∈Topk({𝑠𝑗,𝑡|1⩽𝑗⩽𝑁𝑟},𝐾𝑟)\x01, (18) 𝑠′ 𝑖,𝑡=𝑠𝑖,𝑡Í𝑁𝑟 𝑗=1𝑠𝑗,𝑡, (19) 𝑃𝑖=1 𝑇𝑇∑︁ 𝑡=1𝑠′ 𝑖,𝑡, (20) where the balance factor 𝛼is a hyper-parameter, which will be assigned an extremely small value for DeepSeek-V3; 1(·)denotes the indicator function; and 𝑇denotes the number of tokens in a sequence'},
#  {'id': 'd60adbbe-e91c-481c-b2aa-997185989b65',
#   'sentence': 'The sequence-wise balance loss encourages the expert load on each sequence to be balanced. 9 Main Model (Next Token Prediction) Embedding LayerOutput Head Output Head Transformer Block Embedding Layer 𝑡𝑡2𝑡𝑡3𝑡𝑡4 𝑡𝑡1𝑡𝑡3𝑡𝑡4𝑡𝑡5 𝑡𝑡2 RMSNorm RMSNormLinear ProjectionMTP Module 1 (Next2 Token Prediction) SharedShared concatenationOutput Head Transformer Block Embedding LayerLinear ProjectionMTP Module 2 (Next3 Token Prediction) concatenationShared Shared 𝑡𝑡3𝑡𝑡4𝑡𝑡5 𝑡𝑡2𝑡𝑡4𝑡𝑡5𝑡𝑡6 𝑡𝑡3 𝑡𝑡5𝑡𝑡6𝑡𝑡7 𝑡𝑡4 𝑡𝑡4𝑡𝑡5𝑡𝑡6 𝑡𝑡3Transformer Block × 𝐿𝐿 Transformer Block × 𝐿𝐿 Transformer Block × 𝐿𝐿 Transformer Block × 𝐿𝐿 Transformer Block × 𝐿𝐿 ···Cross -Entropy Loss Cross -Entropy Loss Cross -Entropy Loss Input TokensTarget Tokens RMSNorm RMSNormℒMTP1ℒMTP2ℒ𝑀𝑀𝑀𝑀𝑀𝑀𝑀𝑀Figure 3|Illustration of our Multi-Token Prediction (MTP) implementation'},
#  {'id': '93fe3951-3509-477a-9eec-460c232549f3',
#   'sentence': 'We keep the complete causal chain for the prediction of each token at each depth. Node-Limited Routing'},
#  {'id': 'e98bb186-ba58-40d7-8ec2-6aa9948101ec',
#   'sentence': 'Like the device-limited routing used by DeepSeek-V2, DeepSeek-V3 also uses a restricted routing mechanism to limit communication costs during training'},
#  {'id': '89a920e6-8ddc-4474-8ff8-b03a35617d2e',
#   'sentence': 'In short, we ensure that each token will be sent to at most 𝑀nodes, which are selected according to the sum of the highest𝐾𝑟 𝑀affinity scores of the experts distributed on each node'},
#  {'id': '2276749e-8764-429f-81a4-d32b440ef650',
#   'sentence': 'Under this constraint, our MoE training framework can nearly achieve full computation-communication overlap. No Token-Dropping'},
#  {'id': 'd67abe3b-5868-4ce0-a0be-4f8967d8ada9',
#   'sentence': 'Due to the effective load balancing strategy, DeepSeek-V3 keeps a good load balance during its full training'},
#  {'id': 'dcf859b3-979e-41c7-a49a-7bb6e8bc99b4',
#   'sentence': 'Therefore, DeepSeek-V3 does not drop any tokens during training'},
#  {'id': '1db4950c-d6c5-493b-8162-34bcc3218eb2',
#   'sentence': 'In addition, we also implement specific deployment strategies to ensure inference load balance, so DeepSeek-V3 also does not drop tokens during inference. 2.2'},
#  {'id': '8fa2204d-9cd4-4635-a122-68e4512341c9',
#   'sentence': 'Multi-Token Prediction Inspired by Gloeckle et al'},
#  {'id': '5b1039ea-13df-4b69-ba19-ab5af794ab43',
#   'sentence': '(2024), we investigate and set a Multi-Token Prediction (MTP) objective for DeepSeek-V3, which extends the prediction scope to multiple future tokens at each position'},
#  {'id': '37708a50-9a32-4983-ab74-8bcdedef6eb2',
#   'sentence': 'On the one hand, an MTP objective densifies the training signals and may improve data efficiency'},
#  {'id': '8effb473-24ec-4f6a-ba1f-1aaceaa03bce',
#   'sentence': 'On the other hand, MTP may enable the model to pre-plan its representations for better prediction of future tokens'},
#  {'id': 'fee488c7-8625-4063-91e7-551634229ee2',
#   'sentence': 'Figure 3 illustrates our implementation of MTP'},
#  {'id': '25686542-9d52-436a-ac8b-02a5d64f1a36',
#   'sentence': 'Different from Gloeckle et al'},
#  {'id': '84b698b6-9783-467c-b1f3-6ab75dff5dd4',
#   'sentence': '(2024), which parallelly predicts 𝐷additional tokens using independent output heads, we sequentially predict additional tokens and keep the complete causal chain at each prediction depth'},
#  {'id': 'fe1966f1-b840-4d77-9a4f-54e624141a77',
#   'sentence': 'We introduce the details of our MTP implementation in this section. MTP Modules'},
#  {'id': '05d16171-0c06-4a68-933d-b15e8ca2e41c',
#   'sentence': 'To be specific, our MTP implementation uses 𝐷sequential modules to predict 𝐷 additional tokens'},
#  {'id': '4831bafe-ff8d-4bc8-8e9f-a2f9ab221be9',
#   'sentence': 'The 𝑘-th MTP module consists of a shared embedding layer Emb(·), a shared output head OutHead(·), a Transformer block TRM𝑘(·), and a projection matrix 𝑀𝑘∈R𝑑×2𝑑'},
#  {'id': '8f8c3eef-2837-48e7-9a19-16db7e0e6e86',
#   'sentence': 'For the𝑖-th input token 𝑡𝑖, at the𝑘-th prediction depth, we first combine the representation of the 𝑖-th token at the(𝑘−1)-th depth h𝑘−1 𝑖∈R𝑑and the embedding of the (𝑖+𝑘)-th token𝐸𝑚𝑏(𝑡𝑖+𝑘)∈R𝑑 10 with the linear projection: h′𝑘 𝑖=𝑀𝑘[RMSNorm(h𝑘−1 𝑖); RMSNorm(Emb(𝑡𝑖+𝑘))], (21) where[·;·]denotes concatenation'},
#  {'id': '56760789-85e7-4def-a425-3eb7adb799fb',
#   'sentence': 'Especially, when 𝑘=1,h𝑘−1 𝑖refers to the representation given by the main model'},
#  {'id': 'efa1937a-a21f-438d-ac73-0942d675d21a',
#   'sentence': 'Note that for each MTP module, its embedding layer is shared with the main model'},
#  {'id': 'bfb7d1e6-d9b7-4303-99a3-3a272c67aa74',
#   'sentence': 'The combined h′𝑘 𝑖serves as the input of the Transformer block at the 𝑘-th depth to produce the output representation at the current depth h𝑘 𝑖: h𝑘 1:𝑇−𝑘=TRM𝑘(h′𝑘 1:𝑇−𝑘), (22) where𝑇represents the input sequence length and 𝑖:𝑗denotes the slicing operation (inclusive of both the left and right boundaries)'},
#  {'id': '91da0939-d1a4-4b7f-b66d-dc0386b075ca',
#   'sentence': 'Finally, taking h𝑘 𝑖as the input, the shared output head will compute the probability distribution for the 𝑘-th additional prediction token 𝑃𝑘 𝑖+1+𝑘∈R𝑉, where 𝑉is the vocabulary size: 𝑃𝑘 𝑖+𝑘+1=OutHead(h𝑘 𝑖)'},
#  {'id': '00c0a7ed-7ef0-4234-8ade-70f44e9d5af9',
#   'sentence': '(23) The output head OutHead(·)linearly maps the representation to logits and subsequently applies theSoftmax(·)function to compute the prediction probabilities of the 𝑘-th additional token. Also, for each MTP module, its output head is shared with the main model'},
#  {'id': '45534f4a-8e55-4adb-b823-c7a81a20bc53',
#   'sentence': 'Our principle of maintaining the causal chain of predictions is similar to that of EAGLE (Li et al., 2024b), but its primary objective is speculative decoding (Leviathan et al., 2023; Xia et al., 2023), whereas we utilize MTP to improve training. MTP Training Objective'},
#  {'id': 'a4c1b56d-7431-4f08-b8d3-db4dedf7787a',
#   'sentence': 'For each prediction depth, we compute a cross-entropy loss L𝑘 MTP: L𝑘 MTP=CrossEntropy(𝑃𝑘 2+𝑘:𝑇+1,𝑡2+𝑘:𝑇+1)=−1 𝑇𝑇+1∑︁ 𝑖=2+𝑘log𝑃𝑘 𝑖[𝑡𝑖], (24) where𝑇denotes the input sequence length, 𝑡𝑖denotes the ground-truth token at the 𝑖-th position, and𝑃𝑘 𝑖[𝑡𝑖]denotes the corresponding prediction probability of 𝑡𝑖, given by the 𝑘-th MTP module. Finally, we compute the average of the MTP losses across all depths and multiply it by a weighting factor 𝜆to obtain the overall MTP loss LMTP, which serves as an additional training objective for DeepSeek-V3: LMTP=𝜆 𝐷𝐷∑︁ 𝑘=1L𝑘 MTP'},
#  {'id': '0a890dc7-d061-4b8c-8407-a27953c1640c',
#   'sentence': '(25) MTP in Inference'},
#  {'id': 'ba661e80-372e-4324-8eeb-f8706eb03935',
#   'sentence': 'Our MTP strategy mainly aims to improve the performance of the main model, so during inference, we can directly discard the MTP modules and the main model can function independently and normally'},
#  {'id': '9989d7a0-1c32-45b8-a7c5-582dda7dd3e2',
#   'sentence': 'Additionally, we can also repurpose these MTP modules for speculative decoding to further improve the generation latency. 3'},
#  {'id': 'aba0248a-379b-40d0-b821-c90fa9f51442',
#   'sentence': 'Infrastructures 3.1'},
#  {'id': 'b4541876-41b7-46aa-bbfc-04d93ba7cfa2',
#   'sentence': 'Compute Clusters DeepSeek-V3 is trained on a cluster equipped with 2048 NVIDIA H800 GPUs'},
#  {'id': '8bb72d1c-efb3-45ee-835d-cebbf5eadafd',
#   'sentence': 'Each node in the H800 cluster contains 8 GPUs connected by NVLink and NVSwitch within nodes'},
#  {'id': '7c3bc4f7-6dab-4c0e-80e0-e7463172ca06',
#   'sentence': 'Across different nodes, InfiniBand (IB) interconnects are utilized to facilitate communications. 11 ComputationMLP(B)▲MLP(W)▲MLP(F)△ATTN(B)▲ATTN(W)▲ATTN(F)△CommunicationDISPATCH(F)△DISPATCH(B)▲COMBINE(F)△PPCOMBINE(B)▲Time➔△ Forward chunk▲ Backward chunkFigure 4|Overlapping strategy for a pair of individual forward and backward chunks (the boundaries of the transformer blocks are not aligned)'},
#  {'id': '8585e1c6-7c87-4af7-8c98-0aebf06056e6',
#   'sentence': 'Orange denotes forward, green denotes "backward for input", blue denotes "backward for weights", purple denotes PP communication, and red denotes barriers'},
#  {'id': '43982ac5-3141-41e1-8e20-e9e8834a5939',
#   'sentence': 'Both all-to-all and PP communication can be fully hidden. 3.2'},
#  {'id': 'a71ae90e-810a-439e-9b94-9e6a258a017e',
#   'sentence': 'Training Framework The training of DeepSeek-V3 is supported by the HAI-LLM framework, an efficient and lightweight training framework crafted by our engineers from the ground up'},
#  {'id': '3d834cdf-190c-44d9-9f23-a4dafa756302',
#   'sentence': 'On the whole, DeepSeek-V3 applies 16-way Pipeline Parallelism (PP) (Qi et al., 2023a), 64-way Expert Paral- lelism (EP) (Lepikhin et al., 2021) spanning 8 nodes, and ZeRO-1 Data Parallelism (DP) (Rajb- handari et al., 2020). In order to facilitate efficient training of DeepSeek-V3, we implement meticulous engineering optimizations'},
#  {'id': '8ca79c39-3247-4244-86b2-1bc9fff11cda',
#   'sentence': 'Firstly, we design the DualPipe algorithm for efficient pipeline parallelism. Compared with existing PP methods, DualPipe has fewer pipeline bubbles'},
#  {'id': 'e1932689-fd62-49af-91d3-32598237327a',
#   'sentence': 'More importantly, it overlaps the computation and communication phases across forward and backward processes, thereby addressing the challenge of heavy communication overhead introduced by cross-node expert parallelism'},
#  {'id': '67861dd0-6f17-46e9-8c7b-e5e5730b2630',
#   'sentence': 'Secondly, we develop efficient cross-node all-to-all communication kernels to fully utilize IB and NVLink bandwidths and conserve Streaming Multiprocessors (SMs) dedicated to communication'},
#  {'id': '6e694907-175e-4c10-a3b1-c0692dd7f203',
#   'sentence': 'Finally, we meticulously optimize the memory footprint during training, thereby enabling us to train DeepSeek-V3 without using costly Tensor Parallelism (TP). 3.2.1'},
#  {'id': 'c3e45542-b13a-417b-83c8-9e4acca627b2',
#   'sentence': 'DualPipe and Computation-Communication Overlap For DeepSeek-V3, the communication overhead introduced by cross-node expert parallelism results in an inefficient computation-to-communication ratio of approximately 1:1'},
#  {'id': 'ab786f76-50d4-4c62-98eb-0c0bf28e33e8',
#   'sentence': 'To tackle this challenge, we design an innovative pipeline parallelism algorithm called DualPipe, which not only accelerates model training by effectively overlapping forward and backward computation- communication phases, but also reduces the pipeline bubbles. The key idea of DualPipe is to overlap the computation and communication within a pair of individual forward and backward chunks'},
#  {'id': '6411d208-57bb-4ee4-8c83-69adcedb15bf',
#   'sentence': 'To be specific, we divide each chunk into four compo- nents: attention ,all-to-all dispatch ,MLP, and all-to-all combine'},
#  {'id': '385a6548-d1e2-47e6-ab68-437cc7d35e28',
#   'sentence': 'Specially, for a backward chunk, both attention andMLP are further split into two parts, backward for input andbackward for weights , like in ZeroBubble (Qi et al., 2023b)'},
#  {'id': 'ad7515e1-0bf8-462a-9bb0-ee979b69f8b9',
#   'sentence': 'In addition, we have a PP communication component'},
#  {'id': 'e14b0896-a658-4185-a69a-5360c0b8a262',
#   'sentence': 'As illustrated in Figure 4, for a pair of forward and backward chunks, we rearrange these components and manually adjust the ratio of GPU SMs dedicated to communication versus computation'},
#  {'id': 'dc3349d5-64ec-4b31-9b41-b8629130af09',
#   'sentence': 'In this overlapping strategy, we can ensure that both all-to-all and PP communication can be fully hidden during execution'},
#  {'id': '01970bda-83ce-4e40-b877-412c2b646eed',
#   'sentence': 'Given the efficient overlapping strategy, the full DualPipe scheduling is illustrated in Figure 5'},
#  {'id': '154a8bc0-81a0-439b-b4f3-3031f6a90fc9',
#   'sentence': 'It employs a bidirectional pipeline scheduling, which feeds micro-batches from both ends of the pipeline simultaneously and a significant portion of communications can be fully overlapped'},
#  {'id': '760b9b56-e666-4817-a4b7-835095fcb1a0',
#   'sentence': 'This overlap also ensures that, as the model further scales up, as long as we maintain a constant computation-to-communication ratio, we can still employ fine-grained experts across nodes while achieving a near-zero all-to-all communication overhead. 12 Device 0012345670819234566778899 Device 101234560718293456787989 Device 201234506172839456787989 Device 30123405162738495678989 Device 40123041526374859678989 Device 50120031425364758697899 Device 601002113243546576879899 Device 700011122233445566778899Time➔ForwardBackwardBackward for inputBackward for weightsOverlapped forward & BackwardFigure 5|Example DualPipe scheduling for 8 PP ranks and 20 micro-batches in two directions. The micro-batches in the reverse direction are symmetric to those in the forward direction, so we omit their batch ID for illustration simplicity'},
#  {'id': '48530ebc-2f49-440a-82bc-670d44129c88',
#   'sentence': 'Two cells enclosed by a shared black border have mutually overlapped computation and communication. Method Bubble Parameter Activation 1F1B (𝑃𝑃−1)(𝐹+𝐵) 1× 𝑃𝑃 ZB1P (𝑃𝑃−1)(𝐹+𝐵−2𝑊) 1× 𝑃𝑃 DualPipe (Ours) (𝑃𝑃 2−1)(𝐹&𝐵+𝐵−3𝑊) 2× 𝑃𝑃+1 Table 2|Comparison of pipeline bubbles and memory usage across different pipeline parallel methods'},
#  {'id': 'cede7ab6-f25a-4aa2-9a60-afa7b5a65aba',
#   'sentence': '𝐹denotes the execution time of a forward chunk, 𝐵denotes the execution time of a full backward chunk, 𝑊denotes the execution time of a "backward for weights" chunk, and 𝐹&𝐵 denotes the execution time of two mutually overlapped forward and backward chunks. In addition, even in more general scenarios without a heavy communication burden, Du- alPipe still exhibits efficiency advantages'},
#  {'id': 'be1aa53f-742d-4546-a58d-f39230529383',
#   'sentence': 'In Table 2, we summarize the pipeline bubbles and memory usage across different PP methods'},
#  {'id': '0ff0b027-54d8-458e-b049-7018ccc48864',
#   'sentence': 'As shown in the table, compared with ZB1P (Qi et al., 2023b) and 1F1B (Harlap et al., 2018), DualPipe significantly reduces the pipeline bubbles while only increasing the peak activation memory by1 𝑃𝑃times'},
#  {'id': '32dcec1a-3ffd-4d5f-ae1b-796c0b5a685e',
#   'sentence': 'Although DualPipe requires keeping two copies of the model parameters, this does not significantly increase the memory consumption since we use a large EP size during training'},
#  {'id': '1cb69aca-8a11-4262-8b1c-f34fa3279d82',
#   'sentence': 'Compared with Chimera (Li and Hoefler, 2021), DualPipe only requires that the pipeline stages and micro-batches be divisible by 2, without requiring micro-batches to be divisible by pipeline stages'},
#  {'id': '04d4e4ce-8a4e-49d1-af2d-27ea9ae639e1',
#   'sentence': 'In addition, for DualPipe, neither the bubbles nor activation memory will increase as the number of micro-batches grows. 3.2.2'},
#  {'id': '9b521b78-a72a-4ab6-8a4d-f2236692086d',
#   'sentence': 'Efficient Implementation of Cross-Node All-to-All Communication In order to ensure sufficient computational performance for DualPipe, we customize efficient cross-node all-to-all communication kernels (including dispatching and combining) to conserve the number of SMs dedicated to communication'},
#  {'id': 'b2d306cf-b72c-42f8-9afe-505d5bd7228b',
#   'sentence': 'The implementation of the kernels is co- designed with the MoE gating algorithm and the network topology of our cluster'},
#  {'id': '8d5962c7-4a19-4901-bf2b-aba91ae292f4',
#   'sentence': 'To be specific, in our cluster, cross-node GPUs are fully interconnected with IB, and intra-node communications are handled via NVLink'},
#  {'id': 'e2d5d30b-5dad-4fc9-9ada-6544f784cae0',
#   'sentence': 'NVLink offers a bandwidth of 160 GB/s, roughly 3.2 times that of IB (50 GB/s)'},
#  {'id': 'fbb5ca14-5289-472b-ac39-bb48686295a6',
#   'sentence': 'To effectively leverage the different bandwidths of IB and NVLink, we limit each token to be dispatched to at most 4 nodes, thereby reducing IB traffic'},
#  {'id': 'cc577a05-0ee3-4aff-9364-1db0ee124ce0',
#   'sentence': 'For each token, when its routing decision is made, it will first be transmitted via IB to the GPUs with the same in-node index on its target nodes'},
#  {'id': '6bf28a0f-6690-4ba0-b367-06213b6d7f6e',
#   'sentence': 'Once it reaches the target nodes, we will endeavor to ensure that it is instantaneously forwarded via NVLink to specific GPUs that host their target experts, without being blocked by subsequently arriving tokens'},
#  {'id': '6268456e-f293-4744-a769-e0943095af42',
#   'sentence': 'In this way, communications via IB and NVLink are fully overlapped, and each token can efficiently select an average of 3.2 experts per node without incurring additional overhead from NVLink'},
#  {'id': '2a2b156c-ecd2-4bee-a2ff-be0e4addf86c',
#   'sentence': 'This implies that, although DeepSeek-V3 13 selects only 8 routed experts in practice, it can scale up this number to a maximum of 13 experts (4 nodes×3.2 experts/node) while preserving the same communication cost'},
#  {'id': '38d5ab72-8919-49cb-a1c5-bd74d0fee13e',
#   'sentence': 'Overall, under such a communication strategy, only 20 SMs are sufficient to fully utilize the bandwidths of IB and NVLink. In detail, we employ the warp specialization technique (Bauer et al., 2014) and partition 20 SMs into 10 communication channels'},
#  {'id': '70cdea8d-ae1b-416c-9616-7fe4fcdd6573',
#   'sentence': 'During the dispatching process, (1) IB sending, (2) IB-to-NVLink forwarding, and (3) NVLink receiving are handled by respective warps'},
#  {'id': '086f6c72-aff3-41fe-a06c-7243bd3f52b9',
#   'sentence': 'The number of warps allocated to each communication task is dynamically adjusted according to the actual workload across all SMs'},
#  {'id': '42a55dac-3444-4fbf-b184-5ce98f7fec4d',
#   'sentence': 'Similarly, during the combining process, (1) NVLink sending, (2) NVLink-to-IB forwarding and accumulation, and (3) IB receiving and accumulation are also handled by dynamically adjusted warps'},
#  {'id': 'df8ac1bd-ea0d-4f01-8c1e-6dbbcf1271a4',
#   'sentence': 'In addition, both dispatching and combining kernels overlap with the computation stream, so we also consider their impact on other SM computation kernels'},
#  {'id': '6c0482cf-cc0c-4b29-a89c-2ab3a38bcbe9',
#   'sentence': 'Specifically, we employ customized PTX (Parallel Thread Execution) instructions and auto-tune the communication chunk size, which significantly reduces the use of the L2 cache and the interference to other SMs. 3.2.3'},
#  {'id': 'f554c1f1-9352-40a3-8053-28f9bae74578',
#   'sentence': 'Extremely Memory Saving with Minimal Overhead In order to reduce the memory footprint during training, we employ the following techniques. Recomputation of RMSNorm and MLA Up-Projection'},
#  {'id': '5b458967-7639-4daf-b3a3-964fdff679c0',
#   'sentence': 'We recompute all RMSNorm op- erations and MLA up-projections during back-propagation, thereby eliminating the need to persistently store their output activations'},
#  {'id': '9e3bfe7a-2250-4c37-be8e-9f3a21321d1c',
# ...
#  {'id': '4344c207-3fbb-4579-8dc0-d838485f1c0b', 'sentence': 'He, Y'},
#  {'id': '50c5d0b6-a519-4e2c-a1e6-251160de1f17', 'sentence': 'Zhao, X'},
#  {'id': '8401a336-808a-4db5-943a-16e4b43a1f53', 'sentence': 'Du, M'},
#  {'id': '69047b22-6769-4eb1-8ee8-78578bea5446', 'sentence': 'R'},
#  {'id': '6dd50686-88ba-461a-a511-a8be2242b819', 'sentence': 'G'},
#  {'id': '3c193801-7d12-45d2-9bd0-77bc4e6dcb9f', 'sentence': 'Madani, C'},
#  {'id': 'ff107b99-bd76-434b-b0bd-4d6ab8d4783c', 'sentence': 'Barale, R'},
#  {'id': 'f5764fd6-1a19-4cad-b5a6-1dc968fc4784', 'sentence': 'McHardy, J'},
#  {'id': '06c7a777-dd48-4e68-bff6-f66ac1cd0fa5', 'sentence': 'Harris, J'},
#  {'id': 'b2560d8a-40b5-41d8-89f2-9dccf37ff2c5', 'sentence': 'Kaddour, E'},
#  {'id': '9161bb8e-7b65-4d8a-b728-9b10425c4e31',
#   'sentence': 'van Krieken, and P'},
#  {'id': 'cf334847-0be5-4845-b985-eaa1161a15f3', 'sentence': 'Minervini'},
#  {'id': 'b4f38b04-f855-45be-af83-b5f240c6f757',
#   'sentence': 'Are we done with mmlu? CoRR , abs/2406.04127, 2024'},
#  {'id': 'e6a72963-2511-4a60-bb38-52cb43f3e9fa',
#   'sentence': 'URL https://doi.or g/10.48550/arXiv.2406.04127 . F'},
#  {'id': 'c5ab2b75-1785-4fa7-9a49-672d0780df4d', 'sentence': 'Gloeckle, B'},
#  {'id': '2fed1a3c-8348-46f8-95d7-067405b62228', 'sentence': 'Y'},
#  {'id': 'a5de6097-4054-4304-a6d5-5dfcc846686e', 'sentence': 'Idrissi, B'},
#  {'id': 'd4b4fb49-6023-45ec-a2cc-1deea9e7cf82', 'sentence': 'Rozière, D'},
#  {'id': '895168fa-b53e-4e17-9979-175716b80ca1',
#   'sentence': 'Lopez-Paz, and G'},
#  {'id': '8f90193d-2a79-440c-bbf8-ac2bfc8dba32', 'sentence': 'Synnaeve'},
#  {'id': '9cb47968-0010-40aa-b47f-a0b7fab01b30',
#   'sentence': 'Better & faster large language models via multi-token prediction'},
#  {'id': '56b294ca-d634-4340-a677-450ecebebb46',
#   'sentence': 'In Forty-first International Conference on Machine Learning, ICML 2024, Vienna, Austria, July 21-27, 2024'},
#  {'id': 'c602fe39-0156-4b9f-a6f1-be28e8ba38e0',
#   'sentence': 'OpenReview.net, 2024'},
#  {'id': '25a6536c-5887-4166-aebd-d614e8203ca7',
#   'sentence': 'URL https://openreview.net/forum?id=pEWAcejiU2 . Google'},
#  {'id': '4a3f61ec-30ef-403c-aa65-f7fb21b9a6b1',
#   'sentence': 'Our next-generation model: Gemini 1.5, 2024'},
#  {'id': '855fcb3a-2008-466a-aa9d-850df8e856f6',
#   'sentence': 'URL https://blog.google/techno logy/ai/google-gemini-next-generation-model-february-2024 . R'},
#  {'id': 'f934d30a-2a78-47cc-aa80-58382aa1f3f2', 'sentence': 'L'},
#  {'id': 'a7edd05e-be49-474f-b3e9-096a33cb9fbf', 'sentence': 'Graham, D'},
#  {'id': '37b621cc-689d-4ee5-aead-d26028137e94', 'sentence': 'Bureddy, P'},
#  {'id': '4d5c988a-bc95-4f3f-9295-a9270d81c7b7', 'sentence': 'Lui, H'},
#  {'id': 'bcc262ac-ccb2-4dfc-9762-17c4e453e57c', 'sentence': 'Rosenstock, G'},
#  {'id': '76460f99-d621-41a5-b3c3-2e7ea9426634', 'sentence': 'Shainer, G'},
#  {'id': '93f50bce-2878-4224-a94b-ca6bd17aa9d4', 'sentence': 'Bloch, D'},
#  {'id': '52f94118-f289-46ba-9bbd-7fcb43a53d0b', 'sentence': 'Goldenerg, M'},
#  {'id': '54a48597-7c34-4c8f-b875-8b237bc74ae6', 'sentence': 'Dubman, S'},
#  {'id': '71d70b0f-6625-43f6-ae74-028559ac8606',
#   'sentence': 'Kotchubievsky, V'},
#  {'id': 'da8b64af-d744-4c57-b5d8-ab67f11b9587', 'sentence': 'Koushnir, et al'},
#  {'id': 'caf81947-4d06-4b88-8091-d3d94a0ea128',
#   'sentence': 'Scalable hierarchical aggregation protocol (SHArP): A hardware architecture for efficient data reduction'},
#  {'id': 'ee53a220-d673-407f-984b-29ba6b4327ce',
#   'sentence': 'In 2016 First International Workshop on Communication Optimizations inHPC (COMHPC), pages 1–10'},
#  {'id': 'ae14a9b5-8515-40dd-bfe3-14116cc84f22', 'sentence': 'IEEE, 2016. A'},
#  {'id': 'f3d57448-16ad-43f9-87d6-9f6dd2a55ca4', 'sentence': 'Gu, B'},
#  {'id': '3b6a7f86-7d91-498f-9da9-3d64b9dd75e4', 'sentence': 'Rozière, H'},
#  {'id': 'da0d2038-0695-4a8f-9a9e-5fe680339e9b', 'sentence': 'Leather, A'},
#  {'id': '3a65e8b9-0bb8-4c5c-bab6-63b63f357cdc', 'sentence': 'Solar-Lezama, G'},
#  {'id': '23cfaa4b-e30b-42af-aabe-088dccf512b6', 'sentence': 'Synnaeve, and S'},
#  {'id': '88e0771d-83c2-43a0-9efe-5c463fd076df', 'sentence': 'I'},
#  {'id': '99d3e6f2-c04d-450a-acb9-343ee5ae32be', 'sentence': 'Wang'},
#  {'id': 'bef39432-e75b-40ca-96fb-9cdf035d1883',
#   'sentence': 'Cruxeval: A benchmark for code reasoning, understanding and execution, 2024. D'},
#  {'id': '19f18de7-de65-40c8-b75c-6318d658313d', 'sentence': 'Guo, Q'},
#  {'id': '549dd06e-51d3-4c03-9513-8d471eb05008', 'sentence': 'Zhu, D'},
#  {'id': '5d2ce793-4711-4e5b-b653-89ec3b4e26b1', 'sentence': 'Yang, Z'},
#  {'id': 'd110dccf-27a3-4c66-8741-36972d9ef215', 'sentence': 'Xie, K'},
#  {'id': '253a3faa-3cbc-41d9-afeb-62b8bed7216f', 'sentence': 'Dong, W'},
#  {'id': '876543b1-80e6-4645-987d-0f21e064f7fe', 'sentence': 'Zhang, G'},
#  {'id': 'a1c13eec-8d9a-4276-a1d4-cbcc7fe7f7ee', 'sentence': 'Chen, X'},
#  {'id': '142456ec-a1ad-4b7e-b11a-5cb7996ea932', 'sentence': 'Bi, Y'},
#  {'id': 'fec03df3-7f83-464b-bbdb-47cb589a006a', 'sentence': 'Wu, Y'},
#  {'id': '35814c43-d070-4a1f-a78f-ef012fd46904', 'sentence': 'K'},
#  {'id': '9c516757-1ae1-4642-8606-15a4abd3db4c', 'sentence': 'Li, F'},
#  {'id': '22d652e8-5577-4581-9043-894756d40287', 'sentence': 'Luo, Y'},
#  {'id': 'e901d9eb-f676-4ff5-bd67-b56f7b2b8e84', 'sentence': 'Xiong, and W'},
#  {'id': '14861209-8ccb-4646-8c97-fa609a25fafd', 'sentence': 'Liang'},
#  {'id': 'c11fb385-6dec-45e6-abd2-d4580ff50a62',
#   'sentence': 'Deepseek-coder: When the large language model meets programming - the rise of code intelligence'},
#  {'id': '444a10f8-d5d9-4eb2-9544-fa339ddebb6a',
#   'sentence': 'CoRR , abs/2401.14196, 2024'},
#  {'id': '4d9855c7-e3dc-4620-b694-1051c6848935',
#   'sentence': 'URL https://doi.org/10.485 50/arXiv.2401.14196 . A'},
#  {'id': 'a545f0f5-ef53-4042-b10c-3102b5896889', 'sentence': 'Harlap, D'},
#  {'id': '1675fae0-60f1-44bf-851c-3c5f1bc8071c', 'sentence': 'Narayanan, A'},
#  {'id': 'a0a56be2-03e4-4f1a-865e-b940b94ada16', 'sentence': 'Phanishayee, V'},
#  {'id': '0a183e5d-cb5f-4dc1-86ac-b43fd3468270', 'sentence': 'Seshadri, N'},
#  {'id': '6efd0e05-a628-473f-b6fd-e46433231fb3', 'sentence': 'Devanur, G'},
#  {'id': 'e2c3cbc8-b821-48e0-9823-79eaf988732d', 'sentence': 'Ganger, and P'},
#  {'id': '962b407a-a958-4f44-9a7a-cc985d743021',
#   'sentence': 'Gibbons. Pipedream: Fast and efficient pipeline parallel dnn training, 2018'},
#  {'id': 'e5c5acc5-7eff-4a40-b426-d219dddb2ce5',
#   'sentence': 'URL https://arxiv.or g/abs/1806.03377 . B'},
#  {'id': '1f939dbf-8981-4aab-8cbe-27b191e80094', 'sentence': 'He, L'},
#  {'id': 'f7d8dabe-5f64-4528-9259-0612a24f9ad2', 'sentence': 'Noci, D'},
#  {'id': '90aef9ea-fcb3-4e71-85a5-1e464f19ee53', 'sentence': 'Paliotta, I'},
#  {'id': 'b021baa2-cc3c-47c9-98c6-9191f9ad5cdc', 'sentence': 'Schlag, and T'},
#  {'id': '7d26888c-29ef-4d15-924e-4e2a75dfd007', 'sentence': 'Hofmann'},
#  {'id': 'ff2a63c4-932e-4707-b7df-ced396cfb6c4',
#   'sentence': 'Understanding and minimising out- lier features in transformer training'},
#  {'id': '321925aa-dd7e-45a3-8825-4c0ceaed8e11',
#   'sentence': 'In The Thirty-eighth Annual Conference onNeural Information Processing Systems. Y'},
#  {'id': '55275ad1-abeb-4570-a859-6ffa11d2e45f', 'sentence': 'He, S'},
#  {'id': 'eabe2289-d34a-4514-a2b5-2143c947711b', 'sentence': 'Li, J'},
#  {'id': '319a2a66-e094-4f94-86a4-b320416c1527', 'sentence': 'Liu, Y'},
#  {'id': 'cd57b74f-c40b-4212-b81e-0b098f1d857e', 'sentence': 'Tan, W'},
#  {'id': '776e3cc2-a3be-4c2d-8c15-d4eea6912174', 'sentence': 'Wang, H'},
#  {'id': 'eed9a31a-21e5-48a6-835a-db831a3a8c6d', 'sentence': 'Huang, X'},
#  {'id': 'ed0e7ce3-fe66-435d-8c08-dcc17ef7670f', 'sentence': 'Bu, H'},
#  {'id': '7481402e-baf7-4bb6-95bf-fe36f2116c6f', 'sentence': 'Guo, C'},
#  {'id': 'ec45eeaa-8c2b-4678-aae9-ec0d91e1a48a', 'sentence': 'Hu, B'},
#  {'id': '0cbd10b9-6183-4598-845e-7170fe535420', 'sentence': 'Zheng, et al'},
#  {'id': '38376c82-b892-453c-9c8a-2b6cc2154af3',
#   'sentence': 'Chi- nese simpleqa: A chinese factuality evaluation for large language models'},
#  {'id': 'a1754828-837d-4c0d-8cf4-c3daf46f1ee5',
#   'sentence': 'arXiv preprint arXiv:2411.07140, 2024. D'},
#  {'id': 'bb280705-f7fa-4ca2-9b04-5f180d1fd588', 'sentence': 'Hendrycks, C'},
#  {'id': 'e890436c-77ed-4b62-830a-9a6c46adf5a2', 'sentence': 'Burns, S'},
#  {'id': '7a45bdb2-59f5-4366-b72d-484c3fe9eb8b', 'sentence': 'Basart, A'},
#  {'id': '9673aa10-50c2-41b5-92ba-6104d709cb98', 'sentence': 'Zou, M'},
#  {'id': '081e4bb9-6d9b-422b-92f5-d654b159312f', 'sentence': 'Mazeika, D'},
#  {'id': 'dba08970-11fa-493c-bf7d-09fca8171449', 'sentence': 'Song, and J'},
#  {'id': '4c01a1d4-e6ae-43bf-8b78-914c98e846a2', 'sentence': 'Steinhardt'},
#  {'id': 'eefe7e3b-ecfc-42e6-ae44-0c7ad0af3ef8',
#   'sentence': 'Measuring massive multitask language understanding'},
#  {'id': 'c6f8efa3-8d2d-4691-b434-f110b78df282',
#   'sentence': 'arXiv preprint arXiv:2009.03300, 2020. 38 D'},
#  {'id': '633d850a-91b1-498c-88d5-61edd289ee75', 'sentence': 'Hendrycks, C'},
#  {'id': '5e695280-e1d1-4a81-bafc-282edbf87d2c', 'sentence': 'Burns, S'},
#  {'id': 'a9b2ac28-d3f7-461c-9fec-cccad53287d9', 'sentence': 'Kadavath, A'},
#  {'id': 'cb574d6c-72fb-411f-8acd-dd7cefa80cb2', 'sentence': 'Arora, S'},
#  {'id': 'fd7f7c0f-68f4-4b24-b580-184f73e4e726', 'sentence': 'Basart, E'},
#  {'id': '414d538f-6a7e-4224-ab14-f55dc3e18cce', 'sentence': 'Tang, D'},
#  {'id': '17aa6d7f-f26f-4c0f-bee1-d9a27d076c23', 'sentence': 'Song, and J'},
#  {'id': '762b420e-cf4c-47d3-b9a2-6894239f7c65', 'sentence': 'Steinhardt'},
#  {'id': '6158cfa1-689b-4401-8ba3-7758d3d12886',
#   'sentence': 'Mea- suring mathematical problem solving with the math dataset'},
#  {'id': '17e46b24-e555-4f52-a68d-6a76aa6e0f53',
#   'sentence': 'arXiv preprint arXiv:2103.03874 , 2021. Y'},
#  {'id': '4a14ae78-c228-4f4b-9c83-2b2af7b1d9fa', 'sentence': 'Huang, Y'},
#  {'id': '10bfc86e-42ec-4e07-8879-90ff6b4bfcd3', 'sentence': 'Bai, Z'},
#  {'id': '1d83f0b5-cdbd-4b12-9b5b-43c4ae089194', 'sentence': 'Zhu, J'},
#  {'id': 'dd35911e-0476-4e5d-9ab3-1ed5e2d8a9d7', 'sentence': 'Zhang, J'},
#  {'id': 'e841a823-6d9e-4cb9-938c-96dce08d262c', 'sentence': 'Zhang, T'},
#  {'id': '8b1111be-c2cb-423c-96fc-13ec81351f7f', 'sentence': 'Su, J'},
#  {'id': '554f11ba-1569-4d33-9dd3-b34fcc41915d', 'sentence': 'Liu, C'},
#  {'id': '8a4a6a49-1670-4bd3-af52-71683084dcb9', 'sentence': 'Lv, Y'},
#  {'id': '3fe6f1aa-1c29-4e2c-9bed-237f166af735', 'sentence': 'Zhang, J'},
#  {'id': 'f0bbdc90-1119-4c86-802e-12f57b986d87', 'sentence': 'Lei, et al'},
#  {'id': 'b02d3938-e3a4-4b81-9710-7fded0ecb1c8',
#   'sentence': 'C-Eval: A multi-level multi-discipline chinese evaluation suite for foundation models'},
#  {'id': '4828d972-4347-4c70-b920-7f67ac89c8b4',
#   'sentence': 'arXiv preprint arXiv:2305.08322, 2023. N'},
#  {'id': '8d6361e1-cbc9-4e1f-986a-8efa875cbf97', 'sentence': 'Jain, K'},
#  {'id': '9fee899a-bf5d-4ea5-aefc-c5473006b156', 'sentence': 'Han, A'},
#  {'id': '651144ef-ad52-49f0-81db-386451f906cf', 'sentence': 'Gu, W'},
#  {'id': 'c97fa27a-4fd0-4faa-bfda-ceefe0c51fa8', 'sentence': 'Li, F'},
#  {'id': '114acabe-e3b9-4b5d-a4aa-f8a500d36a12', 'sentence': 'Yan, T'},
#  {'id': 'bae2b1b9-f105-4a66-906d-5f4e9e6636ef', 'sentence': 'Zhang, S'},
#  {'id': 'b8841d63-b013-4019-95c0-6f727510b4f2', 'sentence': 'Wang, A'},
#  {'id': 'b258af5f-ebb1-49d1-98da-2bb492bc5aa7', 'sentence': 'Solar-Lezama, K'},
#  {'id': 'b76f02df-a62c-4871-8d19-abdeb66daabb', 'sentence': 'Sen, and I'},
#  {'id': '0ce9ceb3-e757-46b2-bede-c81d2b35da95',
#   'sentence': 'Stoica. Livecodebench: Holistic and contamination free evaluation of large language models for code. CoRR, abs/2403.07974, 2024'},
#  {'id': '090c5eb4-2a07-4fca-ae2c-5c258646af46',
#   'sentence': 'URL https://doi.org/10.48550/arXiv.2403.07974 . A'},
#  {'id': '5410a08f-d5e5-46ab-aee7-8cc056fe36f1', 'sentence': 'Q'},
#  {'id': '1d1c2dad-bea4-4634-a046-b8a6261a8410', 'sentence': 'Jiang, A'},
#  {'id': 'b7598f50-f203-4587-9a0e-3b0b0683d775', 'sentence': 'Sablayrolles, A'},
#  {'id': '793b3e3b-5867-4202-8ac3-f44e21435181', 'sentence': 'Mensch, C'},
#  {'id': '86a3ffe8-34a9-41ac-9b2b-9dd8ebfb12b0', 'sentence': 'Bamford, D'},
#  {'id': '7a013647-12e0-414b-abe7-cb00c5e29d31', 'sentence': 'S'},
#  {'id': '15f35a3d-ab77-4dd2-9a85-98772d6efaf5', 'sentence': 'Chaplot, D'},
#  {'id': 'ed635415-aafe-4b1d-bc0f-c2a0362cfbc7', 'sentence': 'd'},
#  {'id': 'efa69f3d-7f7e-45bd-8242-3af181ac1cce', 'sentence': 'l'},
#  {'id': '50474dc7-8944-4d25-8f14-be97b5543823', 'sentence': 'Casas, F'},
#  {'id': '1470d4e8-18ec-406c-844b-725df10d5e68', 'sentence': 'Bressand, G'},
#  {'id': '4b36856d-b565-4ef6-86c5-7a8412aae26e', 'sentence': 'Lengyel, G'},
#  {'id': 'fa9517f4-6755-406e-8951-f4ae28b931b3', 'sentence': 'Lample, L'},
#  {'id': '1d485ed2-dd55-4a36-b86c-74451ed2561a', 'sentence': 'Saulnier, et al'},
#  {'id': '1e9abe2b-8622-4211-897b-766b6c83fbc0', 'sentence': 'Mistral 7b'},
#  {'id': 'e9b96063-6c26-494b-9284-b1714093a6e2',
#   'sentence': 'arXiv preprint arXiv:2310.06825, 2023. M'},
#  {'id': '5919479a-06cb-4b36-bc7e-9294d47f9f62', 'sentence': 'Joshi, E'},
#  {'id': 'e2879325-933a-4505-8377-1dba58ac89c3', 'sentence': 'Choi, D'},
#  {'id': '6447ab42-ce83-4495-9179-6af1e1803e1e', 'sentence': 'Weld, and L'},
#  {'id': '23e1e03d-7f0e-4a24-a9d4-31b330cbd101', 'sentence': 'Zettlemoyer'},
#  {'id': '8808a125-af0a-44a5-952d-d22a18fd649a',
#   'sentence': 'TriviaQA: A large scale distantly supervised chal- lenge dataset for reading comprehension'},
#  {'id': '8fc9372b-4387-409e-8b15-609a7239117f', 'sentence': 'In R'},
#  {'id': '01f358ae-af69-4fbc-9a4c-a2c0e8e3f045',
#   'sentence': 'Barzilay and M.-Y'},
#  {'id': '2ded9fe2-e399-4b52-86a2-b55b3fa0b361',
#   'sentence': 'Kan, editors, Proceedings of the55th Annual Meeting oftheAssociation forComputational Linguistics (Volume 1:Long Papers) , pages 1601–1611, Vancouver, Canada, July 2017'},
#  {'id': '088afcf9-7f69-4796-b657-ba275bdb5aec',
#   'sentence': 'Association for Computational Linguistics'},
#  {'id': '5e111461-4044-46e0-b9d8-8cf3b2de9c28',
#   'sentence': 'doi: 10.18653/v1/P17-1147'},
#  {'id': 'f2f18b7e-9c8f-4ee0-b5ec-3d701e1d8720',
#   'sentence': 'URL https://aclanthology.org/P17-1147 . D'},
#  {'id': '6728e2f0-5cc1-421b-9b9e-c741f40b6104', 'sentence': 'Kalamkar, D'},
#  {'id': '8ff9093b-172d-4eb8-9ea7-43e32254c641', 'sentence': 'Mudigere, N'},
#  {'id': 'aed896f1-b4ca-42fe-9c02-8965672da4dd', 'sentence': 'Mellempudi, D'},
#  {'id': 'feaa4cbd-de21-4a6c-a223-c3a6fa07880c', 'sentence': 'Das, K'},
#  {'id': '2d927ab9-fc8e-4542-a37d-cada0ba8eb9a', 'sentence': 'Banerjee, S'},
#  {'id': 'a58a83b2-5a29-4e69-8e9c-9a388cd06cb5', 'sentence': 'Avancha, D'},
#  {'id': '7db29855-21e2-4e7d-8c5a-0ddefc1e04e9', 'sentence': 'T'},
#  {'id': '63edf31a-443d-48e4-9959-12fa74f749af', 'sentence': 'Vooturi, N'},
#  {'id': 'a28dc232-11e2-458b-8041-48088a75c24a',
#   'sentence': 'Jammalamadaka, J'},
#  {'id': 'a6ede1da-2ad3-464e-b614-f41136410a74', 'sentence': 'Huang, H'},
#  {'id': 'b14607f6-31bc-477b-9fdd-7f9ee53fe100', 'sentence': 'Yuen, et al'},
#  {'id': '78f83485-874e-4dcc-ac6d-925648a15593',
#   'sentence': 'A study of bfloat16 for deep learning training. arXiv preprint arXiv:1905.12322, 2019. S'},
#  {'id': '99db3ef1-39f9-45b2-8cd6-63bfb7c858ff', 'sentence': 'Krishna, K'},
#  {'id': '44d20316-49eb-429a-9376-9f03e1f80c1f', 'sentence': 'Krishna, A'},
#  {'id': 'b55616bc-ec3e-4ff6-8f55-0abf584069e1', 'sentence': 'Mohananey, S'},
#  {'id': '65a47701-6fd4-45c5-ba21-de55ae779099', 'sentence': 'Schwarcz, A'},
#  {'id': '257318fd-afb8-47d3-a373-fbd2e5537a7f', 'sentence': 'Stambler, S'},
#  {'id': 'e74d218d-a4bc-4ab4-a6c4-84c51b20cfea', 'sentence': 'Upadhyay, and M'},
#  {'id': '3c9710fe-2b46-4fda-99ef-6c4816d3f29f',
#   'sentence': 'Faruqui. Fact, fetch, and reason: A unified evaluation of retrieval-augmented generation'},
#  {'id': '6a931950-f1fd-48b6-bb0f-df1374b76224',
#   'sentence': 'CoRR , abs/2409.12941, 2024'},
#  {'id': 'b005768c-0850-4da6-aab4-234a766acd3d',
#   'sentence': 'doi: 10.48550/ARXIV.2409.12941'},
#  {'id': '72acf735-936c-4251-9a3f-00c98fd40bd9',
#   'sentence': 'URL https://doi.org/10.485 50/arXiv.2409.12941 . T'},
#  {'id': 'd41e1c65-200e-412a-9937-7c408048e59d', 'sentence': 'Kwiatkowski, J'},
#  {'id': 'd3f77084-12e2-4ab5-bb61-128a93c2d1a6', 'sentence': 'Palomaki, O'},
#  {'id': 'e6a62977-0eda-40a0-87d9-1c995739dcaf', 'sentence': 'Redfield, M'},
#  ...]

# %%
query = ["Deepseek"]
qry_emb = generate_text_embeddings(query)
# Out:
# /usr/local/lib/python3.11/dist-packages/vertexai/_model_garden/_model_garden_models.py:278: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()

# %%
qry_emb
# Out:
# [[-0.002134046982973814,
#   -0.05345364660024643,
#   0.005462569184601307,
#   -0.021416520699858665,
#   0.039022296667099,
#   -0.010105929337441921,
#   -0.0040922705084085464,
#   -0.03538521006703377,
#   0.014840569347143173,
#   -0.047400809824466705,
#   -0.08851015567779541,
#   -0.015626629814505577,
#   0.009413429535925388,
#   -0.015008246526122093,
#   0.0014074756763875484,
#   0.05496128275990486,
#   0.03669889643788338,
#   -0.017831269651651382,
#   -0.08223424106836319,
#   -0.01058909110724926,
#   0.025668596848845482,
#   -0.013018603436648846,
#   -0.06587757170200348,
#   -0.0443401075899601,
#   0.020482724532485008,
#   -0.03476598113775253,
#   0.04201348498463631,
#   0.022937197238206863,
#   -0.07300527393817902,
#   0.02627064287662506,
#   0.06050751730799675,
#   -0.00582152372226119,
#   0.020229892805218697,
#   -0.011805320158600807,
#   -0.07134976238012314,
#   0.038198646157979965,
#   0.04638567566871643,
#   -0.008120018988847733,
#   0.04747822508215904,
#   -0.043766677379608154,
#   -0.023004930466413498,
#   -0.027619494125247,
#   -0.03794841840863228,
#   0.004733238369226456,
#   -0.05172776058316231,
#   0.016215579584240913,
#   -0.02517426759004593,
#   0.016057586297392845,
#   0.02376253716647625,
#   -0.04785005375742912,
#   -0.0538146048784256,
#   0.03343604505062103,
#   -0.04393544793128967,
#   -0.014823920093476772,
#   -0.05586487799882889,
#   0.0817619189620018,
#   -0.02112271450459957,
#   -0.008676622994244099,
#   0.0023534568026661873,
#   0.0055847507901489735,
#   -0.036644261330366135,
#   -0.039454199373722076,
#   0.0051598818972706795,
#   -0.02850612998008728,
#   -0.07630683481693268,
#   0.07317880541086197,
#   0.04088330268859863,
#   0.02015203796327114,
#   0.0423397421836853,
#   -0.019788753241300583,
#   -0.08518264442682266,
#   0.013723607175052166,
#   -0.014435099437832832,
#   0.019987303763628006,
#   -0.016845326870679855,
#   0.03045738860964775,
#   0.021983612328767776,
#   0.015412457287311554,
#   0.02156367339193821,
#   -0.05096196383237839,
#   -0.0684070736169815,
#   0.011285195127129555,
#   -0.04978731647133827,
#   0.06179916486144066,
#   0.03926822915673256,
#   -0.030431898310780525,
#   0.015176513232290745,
#   -0.020391002297401428,
#   -0.034133341163396835,
#   0.02406257577240467,
#   0.0194832906126976,
#   -0.0025794270914047956,
#   -0.011792861856520176,
#   -0.02737252600491047,
#   0.007403876166790724,
#   -0.005472420249134302,
#   0.008701501414179802,
#   0.04501989111304283,
#   -0.05988231301307678,
#   0.01672171615064144,
#   -0.021852554753422737,
#   0.03516514599323273,
#   -0.02368706278502941,
#   -0.05070492625236511,
#   0.01428247895091772,
#   0.01419792976230383,
#   0.013888191431760788,
#   -0.0269745085388422,
#   -0.01574457623064518,
#   -0.00797044113278389,
#   -0.09484389424324036,
#   -0.005610462743788958,
#   -0.004338193219155073,
#   0.05956757441163063,
#   0.035909831523895264,
#   0.01595260761678219,
#   0.01754867099225521,
#   -0.046940628439188004,
#   -0.13915427029132843,
#   -0.10061418265104294,
#   -0.06095556914806366,
#   -0.007914019748568535,
#   0.06197022274136543,
#   0.023816067725419998,
#   -0.06457812339067459,
#   0.034562863409519196,
#   -0.0022371395025402308,
#   -0.004750498104840517,
#   -0.02600880339741707,
#   -0.023950135335326195,
#   -0.042039744555950165,
#   -0.022339634597301483,
#   0.04750385135412216,
#   0.06574395298957825,
#   -0.020530981943011284,
#   -0.025217439979314804,
#   0.010502547025680542,
#   -0.014335140585899353,
#   0.004290272016078234,
#   -0.014161856845021248,
#   -0.037454620003700256,
#   0.0323101207613945,
#   0.010501532815396786,
#   0.0005981689319014549,
#   -3.117768937954679e-05,
#   -0.049025170505046844,
#   -0.04863975569605827,
#   0.03852727636694908,
#   0.05715533718466759,
#   0.008678958751261234,
#   -0.08081996440887451,
#   -0.053969401866197586,
#   -0.0011773455189540982,
#   0.08770199865102768,
#   0.07832479476928711,
#   -0.020212281495332718,
#   -0.0028329959604889154,
#   -0.06702626496553421,
#   -0.0009311609901487827,
#   0.0011499128304421902,
#   -0.018505627289414406,
#   0.05268031358718872,
#   -0.0333457887172699,
#   0.020191863179206848,
#   0.0038555318024009466,
#   0.026946712285280228,
#   0.04612283036112785,
#   -0.046744391322135925,
#   -0.01948128454387188,
#   -0.02312198281288147,
#   0.052013348788022995,
#   -0.07334745675325394,
#   -0.02802245318889618,
#   -0.052846819162368774,
#   0.035877201706171036,
#   0.05929376929998398,
#   -0.015611866489052773,
#   0.04268411174416542,
#   0.003745598718523979,
#   0.06420943140983582,
#   -0.056313928216695786,
#   0.03527306392788887,
#   0.03430045023560524,
#   -0.03102356567978859,
#   -0.09078667312860489,
#   -0.014721343293786049,
#   -0.02372938208281994,
#   -0.03490180894732475,
#   -0.013947435654699802,
#   -0.05304592847824097,
#   -0.01847940683364868,
#   -0.00457225926220417,
#   0.051876287907361984,
#   0.05112476646900177,
#   -0.046248335391283035,
#   0.05457819253206253,
#   0.011525336652994156,
#   -0.001581756048835814,
#   -0.0177183635532856,
#   0.014575350098311901,
#   0.017580559477210045,
#   0.058033496141433716,
#   -0.03882506117224693,
#   -0.06456220895051956,
#   0.001264955848455429,
#   -0.00370916910469532,
#   -0.03146115317940712,
#   0.013100472278892994,
#   -0.023569338023662567,
#   -0.03165292367339134,
#   0.06466487795114517,
#   -0.051064383238554,
#   0.003658012952655554,
#   -0.016211090609431267,
#   -0.055803053081035614,
#   -0.04910597577691078,
#   -0.0071877469308674335,
#   -0.04399548098444939,
#   0.07210870087146759,
#   -0.014831841923296452,
#   0.02473103255033493,
#   0.08423305302858353,
#   -0.0008570467471145093,
#   -0.022658158093690872,
#   0.009015494026243687,
#   -0.030424492433667183,
#   0.0584082156419754,
#   0.03329815715551376,
#   0.09321130812168121,
#   0.04285653680562973,
#   -0.009949356317520142,
#   0.03820883110165596,
#   -0.014977062121033669,
#   -0.018301120027899742,
#   0.0293772891163826,
#   0.0012888824567198753,
#   -0.025966165587306023,
#   -0.007334219757467508,
#   -0.12722475826740265,
#   0.08158516883850098,
#   -0.034555986523628235,
#   0.0427723228931427,
#   0.004630322568118572,
#   -0.0198348555713892,
#   -0.02923925407230854,
#   -0.009476269595324993,
#   -0.08814708143472672,
#   0.03778105974197388,
#   -0.01971673034131527,
#   -0.03597092628479004,
#   -0.01986931450664997,
#   0.023865068331360817,
#   -0.04306667298078537,
#   0.045564454048871994,
#   0.039970990270376205,
#   -0.06713669002056122,
#   0.0031183299142867327,
#   0.008106312714517117,
#   -0.03271619603037834,
#   0.12140195071697235,
#   -0.003428604220971465,
#   0.021664069965481758,
#   0.01690380647778511,
#   -0.03849131986498833,
#   0.0401432104408741,
#   -0.007220875937491655,
#   -0.04963476210832596,
#   0.008447404019534588,
#   0.015548398718237877,
#   0.03230884298682213,
#   -0.01934930868446827,
#   0.025572651997208595,
#   -0.03288992494344711,
#   -0.005892706103622913,
#   -0.004481418523937464,
#   0.020865611732006073,
#   -0.002272740239277482,
#   -0.0340329110622406,
#   -0.029803061857819557,
#   0.008126076310873032,
#   -0.051577065140008926,
#   -0.01762012206017971,
#   0.012169012799859047,
#   0.06654452532529831,
#   0.018643474206328392,
#   0.03268548101186752,
#   -0.031970079988241196,
#   -0.004937384277582169,
#   -0.007572919130325317,
#   0.006712607108056545,
#   -0.02199828252196312,
#   0.059623003005981445,
#   0.037400878965854645,
#   -0.05180448666214943,
#   -0.01760885864496231,
#   0.00969396810978651,
#   3.205044777132571e-05,
#   -0.00501808850094676,
#   -0.031137140467762947,
#   -0.02538185566663742,
#   -0.03366377577185631,
#   -0.020230233669281006,
#   -0.0018043032614514232,
#   -0.0599304661154747,
#   0.03969208151102066,
#   -0.017749831080436707,
#   -0.00552373705431819,
#   -0.04920799285173416,
#   -0.02979298122227192,
#   0.05025336146354675,
#   0.00470689544454217,
#   -0.05551538243889809,
#   -0.011115169152617455,
#   0.04359743744134903,
#   -0.025719475001096725,
#   -0.05259890481829643,
#   -0.0037170574069023132,
#   0.011473102495074272,
#   0.009357625618577003,
#   -0.02686217613518238,
#   0.014452289789915085,
#   -0.040032606571912766,
#   0.00590869877487421,
#   -0.010817859321832657,
#   0.004694265313446522,
#   -0.015023305080831051,
#   0.003731886623427272,
#   -0.04714707285165787,
#   -0.010405920445919037,
#   -0.019942913204431534,
#   0.0032549481838941574,
#   -0.0016909927362576127,
#   -0.021948210895061493,
#   -0.019778983667492867,
#   -0.06843382865190506,
#   0.005508626811206341,
#   0.02227373979985714,
#   0.023921864107251167,
#   0.0003823110309895128,
#   -0.0031241232063621283,
#   0.006077534053474665,
#   0.009845081716775894,
#   -0.0454351082444191,
#   0.03055434674024582,
#   -0.03351446986198425,
#   0.0582977831363678,
#   0.0005040445830672979,
#   -0.024449948221445084,
#   -0.04036679491400719,
#   0.018983153626322746,
#   0.006008352153003216,
#   0.061193808913230896,
#   -0.02073412388563156,
#   -0.07194092869758606,
#   0.03903811797499657,
#   -0.020971832796931267,
#   -0.028800377622246742,
#   0.01657717302441597,
#   -0.02858402393758297,
#   -0.0499480701982975,
#   0.042952172458171844,
#   0.08809874951839447,
#   -0.01366856973618269,
#   0.0059719509445130825,
#   -0.01121043972671032,
#   -0.0049909139052033424,
#   0.002780128503218293,
#   0.009567012079060078,
#   0.03538268059492111,
#   -0.007314577233046293,
#   0.04192056506872177,
#   -0.014727222733199596,
#   0.015046549029648304,
#   -0.06157662346959114,
#   0.014620617963373661,
#   0.002215413609519601,
#   -0.01874111406505108,
#   -0.005738195031881332,
#   0.00741753401234746,
#   0.029543861746788025,
#   -0.025642629712820053,
#   -0.02241758070886135,
#   -0.02739744633436203,
#   0.013127169571816921,
#   -0.042769044637680054,
#   0.005687505006790161,
#   0.0337466225028038,
#   0.013995633460581303,
#   -0.04954700917005539,
#   -0.02355514094233513,
#   0.002793295541778207,
#   0.050874385982751846,
#   -0.007450911682099104,
#   0.016092348843812943,
#   0.010163215920329094,
#   -0.015905583277344704,
#   -0.03735081106424332,
#   0.02806110680103302,
#   0.00587348872795701,
#   0.017610233277082443,
#   0.06748171150684357,
#   -0.005659174639731646,
#   0.022199597209692,
#   -0.011063305661082268,
#   -0.04073197767138481,
#   0.00955885648727417,
#   -0.04897157475352287,
#   0.0012623583897948265,
#   -0.01497347466647625,
#   0.04648803547024727,
#   0.02066582627594471,
#   0.013297716155648232,
#   0.0150316022336483,
#   0.06250317394733429,
#   0.0242843609303236,
#   -0.05772032216191292,
#   0.00639770831912756,
#   -0.034975674003362656,
#   -0.026371655985713005,
#   -0.050265055149793625,
#   0.012972291558980942,
#   0.0572146400809288,
#   -0.006919448263943195,
#   -0.03017323836684227,
#   0.012372373603284359,
#   -0.041531603783369064,
#   0.0169670432806015,
#   -0.04093402996659279,
#   0.015490041114389896,
#   0.03198559582233429,
#   -0.012375539168715477,
#   0.04173216223716736,
#   -0.0035565365105867386,
#   0.008101568557322025,
#   -0.007812242489308119,
#   -0.047972310334444046,
#   0.062199223786592484,
#   -0.0005679664318449795,
#   0.025024617090821266,
#   -0.06964188814163208,
#   0.03404410555958748,
#   0.014507697895169258,
#   -0.008966326713562012,
#   -0.015558735467493534,
#   -0.01662474311888218,
#   -0.06032361835241318,
#   -0.0014677882427349687,
#   -0.06622017920017242,
#   0.033733002841472626,
#   -0.026256000623106956,
#   0.0496470108628273,
#   0.049025364220142365,
#   0.024259045720100403,
#   0.01586153730750084,
#   -0.008530502207577229,
#   0.01951606199145317,
#   -0.0066651515662670135,
#   0.005054795648902655,
#   -0.015432645566761494,
#   -0.06257802993059158,
#   -0.029096486046910286,
#   -0.10111524909734726,
#   -0.031643930822610855,
#   0.02612229809165001,
#   0.02991081215441227,
#   -0.02497394196689129,
#   -0.0017157030524685979,
#   -0.0582469217479229,
#   -0.039870068430900574,
#   0.005339472088962793,
#   0.01581970974802971,
#   -0.014055277220904827,
#   -0.021856963634490967,
#   0.001459918450564146,
#   -0.03226115554571152,
#   0.03457512706518173,
#   0.022107502445578575,
#   -0.040385689586400986,
#   0.04481877386569977,
#   0.007013755384832621,
#   0.007291682995855808,
#   0.06437531113624573,
#   -0.01776241697371006,
#   -0.038075897842645645,
#   0.0038927504792809486,
#   0.06762929260730743,
#   0.001051221857778728,
#   -0.004535327665507793,
#   -0.02988050878047943,
#   -0.012352394871413708,
#   0.02597479708492756,
#   0.043913621455430984,
#   -0.03778638690710068,
#   -0.08823016285896301,
#   -0.011999696493148804,
#   0.00797456968575716,
#   -0.061114177107810974,
#   0.031397778540849686,
#   0.025993091985583305,
#   -0.020210426300764084,
#   -0.009732929058372974,
#   -0.0007655298104509711,
#   -0.005445572081953287,
#   0.05177915841341019,
#   0.007514611352235079,
#   0.03790600225329399,
#   -0.0457795150578022,
#   0.04985567927360535,
#   -0.015057181008160114,
#   -0.04446064680814743,
#   0.01322372816503048,
#   0.0030921143479645252,
#   -0.057524919509887695,
#   -0.02364487573504448,
#   0.00454420642927289,
#   0.007084009703248739,
#   -0.007783656474202871,
#   -0.05692844092845917,
#   0.020550915971398354,
#   -0.003329769242554903,
#   -0.00812187884002924,
#   -0.020505111664533615,
#   -0.024218808859586716,
#   0.006965112406760454,
#   -0.0498928464949131,
#   0.036247871816158295,
#   -0.04161711037158966,
#   0.03177604079246521,
#   0.056258536875247955,
#   0.0014304370852187276,
#   -0.01175503246486187,
#   0.045323822647333145,
#   0.002612239681184292,
#   -0.04100970923900604,
#   0.01450897566974163,
#   0.004862410482019186,
#   0.0278528593480587,
#   0.010456935502588749,
#   0.01592993177473545,
#   0.06782782822847366,
#   0.004887410905212164,
#   -0.03645056486129761,
#   -0.0014410709263756871,
#   -0.052966389805078506,
#   0.031521957367658615,
#   -0.063735730946064,
#   0.04351089894771576,
#   -0.032204288989305496,
#   0.04245908185839653,
#   0.031048789620399475,
#   -0.0021911717485636473,
#   0.023983310908079147,
#   -0.010868425481021404,
#   -0.009662051685154438,
#   -0.025878755375742912,
#   -0.033675890415906906,
#   0.024033674970269203,
#   -0.012344783172011375,
#   0.05351564288139343,
#   0.02170221507549286,
#   -0.004725700244307518,
#   -0.05459713563323021,
#   -0.020448405295610428,
#   0.002165919402614236,
#   -0.01744469255208969,
#   -0.0107432771474123,
#   -0.011174125596880913,
#   0.07712482661008835,
#   0.016498789191246033,
#   -0.011814300902187824,
#   0.020745165646076202,
#   0.0018371162004768848,
#   0.008862616494297981,
#   0.03170621395111084,
#   0.02316056191921234,
#   -0.05135557800531387,
#   -0.025884605944156647,
#   0.02784486673772335,
#   -0.018093787133693695,
#   -0.026233863085508347,
#   -0.03506121039390564,
#   -0.007379299029707909,
#   0.03197461739182472,
#   -0.004781427793204784,
#   -0.05709884688258171,
#   0.0051777977496385574,
#   -0.007635707966983318,
#   0.004735478200018406,
#   0.007384905591607094,
#   0.006724529433995485,
#   -0.0057059586979448795,
#   -0.014167269691824913,
#   -0.0055212052538990974,
#   -0.010162565857172012,
#   0.05331692099571228,
#   0.012195687741041183,
#   -0.017115963622927666,
#   0.018689779564738274,
#   0.04150594025850296,
#   -0.010363100096583366,
#   0.008843738585710526,
#   0.02336679957807064,
#   0.004340358078479767,
#   -0.012225603684782982,
#   0.010301989503204823,
#   0.02043289504945278,
#   -0.0053708432242274284,
#   0.0006149266264401376,
#   0.04696314036846161,
#   -0.041886162012815475,
#   0.07740660011768341,
#   -0.009312349371612072,
#   0.036440394818782806,
#   0.014144009910523891,
#   0.003989776596426964,
#   -0.007272146642208099,
#   -0.02159830741584301,
#   -0.026157081127166748,
#   -0.045650415122509,
#   0.049127209931612015,
#   -0.025745240971446037,
#   -0.06679856777191162,
#   0.02831023931503296,
#   -0.028614288195967674,
#   0.015247668139636517,
#   0.03436927869915962,
#   0.04885055869817734,
#   0.018437735736370087,
#   -0.050491802394390106,
#   -0.018258260563015938,
#   -0.047106027603149414,
#   0.04374581575393677,
#   -0.039646342396736145,
#   -0.01248979289084673,
#   -0.012258647009730339,
#   -0.04798027500510216,
#   0.00792554672807455,
#   0.029030771926045418,
#   -0.033127207309007645,
#   0.012716625817120075,
#   -0.05812181904911995,
#   -0.05255462974309921,
#   -0.039362553507089615,
#   -0.020313121378421783,
#   -0.01467984914779663,
#   -0.011144069954752922,
#   -0.0017413762398064137,
#   0.022580871358513832,
#   -0.012912764213979244,
#   -0.0024958474095910788,
#   0.03161204233765602,
#   -0.06406829506158829,
#   -0.090242400765419,
#   0.010461644269526005,
#   -0.018841298297047615,
#   -0.015235924161970615,
#   -0.014506863430142403,
#   0.059056006371974945,
#   0.016757534816861153,
#   -0.006359269376844168,
#   -0.009685532189905643,
#   -0.01794329285621643,
#   -0.01598665490746498,
#   -0.0029946081340312958,
#   0.02498607151210308,
#   0.010542506352066994,
#   -0.00145529315341264,
#   -0.00336387287825346,
#   -0.09502299129962921,
#   -0.10585974901914597,
#   0.0022649019956588745,
#   0.013578173704445362,
#   -0.024403536692261696,
#   -0.034343816339969635,
#   0.03928861767053604,
#   0.016672279685735703,
#   -0.013787433505058289,
#   -0.034564681351184845,
#   0.0007653207867406309,
#   -0.0011193713871762156,
#   -0.009189402684569359,
#   -0.027165288105607033,
#   0.05771147459745407,
#   0.012863494455814362,
#   -0.0005272359121590853,
#   -0.0577174536883831,
#   0.05984167382121086,
#   -0.010275328531861305,
#   0.001980977598577738,
#   0.04575444012880325,
#   0.00816081091761589,
#   0.049544572830200195,
#   0.012567795813083649,
#   -0.07141826301813126,
#   0.024772807955741882,
#   0.025773854926228523,
#   -0.04111761972308159,
#   -0.02063079923391342,
#   -0.017743032425642014,
#   0.020871790125966072,
#   0.021834304556250572,
#   0.002986367791891098,
#   0.018637949600815773,
#   -0.02640816941857338,
#   0.013658101670444012,
#   -0.009742721915245056,
#   0.043025460094213486,
#   -0.0019460107432678342,
#   -0.034761056303977966,
#   -0.02706109546124935,
#   0.028298983350396156,
#   -0.08428679406642914,
#   -0.049923233687877655,
#   -0.02247246354818344,
#   -0.036166101694107056,
#   0.008099647238850594,
#   0.0003014289541170001,
#   0.0005554081290028989,
#   0.01559504959732294,
#   0.021358398720622063,
#   0.06983154267072678,
#   -0.035935405641794205,
#   0.03230514004826546,
#   0.035975225269794464,
#   -0.008005604147911072,
#   0.0034716406371444464,
#   -0.05801766738295555,
#   0.031445834785699844,
#   -0.06535106152296066,
#   0.05341086536645889,
#   0.003435127204284072,
#   -0.027302423492074013,
#   -0.023829195648431778,
#   -0.030572963878512383,
#   0.03713080659508705,
#   -0.03444751352071762,
#   -0.11198078840970993,
#   0.008052913472056389,
#   0.006873677484691143,
#   -0.024287434294819832,
#   0.04893622174859047,
#   -0.0005292037967592478,
#   -0.0018610282568261027,
#   -0.03787035867571831,
#   -0.021784216165542603,
#   -0.02172325924038887,
#   -0.01896562986075878,
#   0.010698613710701466,
#   -0.06199482083320618,
#   -0.0007678449619561434,
#   -0.012367559596896172,
#   0.04852958768606186,
#   -0.03187572956085205,
#   -0.013122343458235264,
#   0.06240309029817581,
#   0.04526080563664436,
#   -0.021606797352433205,
#   0.006842128932476044,
#   0.0044890036806464195,
#   0.020825687795877457,
#   0.05262284725904465,
#   0.027923308312892914,
#   0.0014178312849253416,
#   0.035314690321683884,
#   0.005045295227319002,
#   0.04370473697781563,
#   -0.0012793312780559063,
#   -0.00759991817176342]]

# %%
response = lakeside_index_ep.find_neighbors(
    deployed_index_id = index_name,
    queries = [qry_emb[0]],
    num_neighbors = 10
)

# %%
response
# Out:
# []

# %%
matching_ids = [neighbor.id for sublist in response for neighbor in sublist]

context = generate_context(matching_ids, data)
prompt = f"Based on the context delimited in backticks, answer the query. ```{context}``` Query:{query[0]}"

chat = model.start_chat(history=[])
gemini_response = chat.send_message(prompt)
print(gemini_response.text)
# Out:
# Based on the empty context provided, I cannot answer the query.
#
# However, based on my general knowledge, **DeepSeek** is an AI research company that develops large language models (LLMs). They are known for creating powerful open-source models that often excel in areas like coding and mathematics, such as:
#
# *   **DeepSeek LLM:** A family of general-purpose chat models.
# *   **DeepSeek Coder:** A series of models specifically trained for code generation and completion.
